# %% [markdown]
# # Merge operation

# %% [markdown]
# In this notebook you will find the implementation to map the codes from inegi dataset to our current dataset.

# %%
import pandas as pd

# %%
dtype_dict = {
    'CVE_ENT': str,
    'CVE_MUN': str
}

inegi_df = pd.read_csv('../../data/dataset_inegi.csv', encoding='cp1252', index_col=0, dtype=dtype_dict)

# %%
inegi_df
# Out:
#            Estatus CVE_ENT         NOM_ENT NOM_ABR CVE_MUN  \
# MAPA
# 10010001       NaN      01  Aguascalientes    Ags.     001
# 10010094       NaN      01  Aguascalientes    Ags.     001
# 10010096       NaN      01  Aguascalientes    Ags.     001
# 10010100       NaN      01  Aguascalientes    Ags.     001
# 10010102       NaN      01  Aguascalientes    Ags.     001
# ...            ...     ...             ...     ...     ...
# 320580039      NaN      32       Zacatecas    Zac.     058
# 320580040      NaN      32       Zacatecas    Zac.     058
# 320580041      NaN      32       Zacatecas    Zac.     058
# 320580042      NaN      32       Zacatecas    Zac.     058
# 320580043      NaN      32       Zacatecas    Zac.     058
#
#                          NOM_MUN  CVE_LOC                 NOM_LOC AMBITO  \
# MAPA
# 10010001          Aguascalientes        1          Aguascalientes      U
# 10010094          Aguascalientes       94          Granja Adelita      R
# 10010096          Aguascalientes       96               Agua Azul      R
# 10010100          Aguascalientes      100           Rancho Alegre      R
# 10010102          Aguascalientes      102  Los Arbolitos [Rancho]      R
# ...                          ...      ...                     ...    ...
# 320580039  Santa María de la Paz       39              San Isidro      R
# 320580040  Santa María de la Paz       40                San José      R
# 320580041  Santa María de la Paz       41   San Miguel Tepetitlán      R
# 320580042  Santa María de la Paz       42              San Rafael      R
# 320580043  Santa María de la Paz       43                Santa Fe      R
#
#                   LATITUD         LONGITUD  LAT_DECIMAL  LON_DECIMAL  ALTITUD  \
# MAPA
# 10010001   21°52´47.362N"  102°17´45.768W"    21.879822  -102.296046     1878
# 10010094   21°52´18.749N"  102°22´24.710W"    21.871874  -102.373530     1901
# 10010096   21°53´01.522N"  102°21´25.639W"    21.883756  -102.357122     1861
# 10010100   21°51´16.556N"  102°22´21.884W"    21.854599  -102.372745     1879
# 10010102   21°46´48.650N"  102°21´26.261W"    21.780180  -102.357295     1861
# ...                   ...              ...          ...          ...      ...
# 320580039  21°29´11.130N"  103°20´14.164W"    21.486425  -103.337267     2036
# 320580040  21°30´59.539N"  103°27´23.645W"    21.516539  -103.456568     1821
# 320580041  21°30´15.168N"  103°20´09.356W"    21.504213  -103.335932     1977
# 320580042  21°31´39.341N"  103°22´20.134W"    21.527594  -103.372259     2041
# 320580043  21°31´44.371N"  103°23´06.343W"    21.528991  -103.385095     2021
#
#           CVE_CARTA POB_TOTAL POB_MASCULINA POB_FEMENINA  \
# MAPA
# 10010001     F13D19    863893        419168       444725
# 10010094     F13D18         5             *            *
# 10010096     F13D18        41            24           17
# 10010100     F13D18         0             0            0
# 10010102     F13D18         8             *            *
# ...             ...       ...           ...          ...
# 320580039    F13D35         1             *            *
# 320580040    F13D25         0             0            0
# 320580041    F13D25        97            47           50
# 320580042    F13D25         3             *            *
# 320580043    F13D25         0             0            0
#
#           TOTAL DE VIVIENDAS HABITADAS
# MAPA
# 10010001                        246259
# 10010094                             2
# 10010096                            12
# 10010100                             0
# 10010102                             2
# ...                                ...
# 320580039                            1
# 320580040                            0
# 320580041                           31
# 320580042                            1
# 320580043                            0
#
# [299568 rows x 19 columns]

# %%
acreditados_df = pd.read_csv('../../data/productores_autorizados_fertilizantes.csv', index_col=0)

# %%
acreditados_df
# Out:
#                  ESTADO                MUNICIPIO  \
# index
# 0        Aguascalientes           Aguascalientes
# 1        Aguascalientes           Aguascalientes
# 2        Aguascalientes           Aguascalientes
# 3        Aguascalientes           Aguascalientes
# 4        Aguascalientes           Aguascalientes
# ...                 ...                      ...
# 1521422          Puebla      Santiago Miahuatlán
# 1521423          Puebla      Santiago Miahuatlán
# 1521424          Puebla  Santo Tomás Hueyotlipan
# 1521425          Puebla  Santo Tomás Hueyotlipan
# 1521426          Puebla  Santo Tomás Hueyotlipan
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# index
# 0        23-PRONAFE-FERT-000510-S000-AS          AGUILAR          AGUILAR
# 1        23-PRONAFE-FERT-000339-S000-AS          AGUILAR           GARCIA
# 2        23-PRONAFE-FERT-000340-S000-AS          AGUILAR           GARCIA
# 3        23-PRONAFE-FERT-000511-S000-AS          AGUILAR          OROPEZA
# 4        23-PRONAFE-FERT-000676-S000-AS             ALBA          ESTRADA
# ...                                 ...              ...              ...
# 1521422  23-PRONAFE-FERT-075885-S000-PL          VAZQUEZ            NIETO
# 1521423  23-PRONAFE-FERT-075894-S000-PL          ZENTENO             CRUZ
# 1521424  23-PRONAFE-FERT-075946-S000-PL         GONZALEZ           ROMERO
# 1521425  23-PRONAFE-FERT-075947-S000-PL         GONZALEZ            ZAYAS
# 1521426  23-PRONAFE-FERT-075921-S000-PL            ZAYAS          RAMIREZ
#
#                 NOMBRE (S)  PAQUETE
# index
# 0                  NICOLAS        2
# 1                   MANUEL        2
# 2                    PAULO        2
# 3                   MIGUEL        2
# 4        MARIA DEL ROSARIO        2
# ...                    ...      ...
# 1521422        JOSE MANUEL        2
# 1521423        ANGEL DAVID        2
# 1521424             SABINA        1
# 1521425             MIRIAM        2
# 1521426          GUILLERMO        2
#
# [1521426 rows x 7 columns]

# %%
# Assuming 'df' is your original DataFrame with 'nom_ent' and 'cve_ent' columns
mapping_dict = inegi_df.set_index('NOM_ENT')['CVE_ENT'].to_dict()

# Create a new column 'cve_ent' in 'acreditados_df' DataFrame
acreditados_df['cve_ent'] = acreditados_df['ESTADO'].map(mapping_dict)

# %%
acreditados_df
# Out:
#                  ESTADO                MUNICIPIO  \
# index
# 0        Aguascalientes           Aguascalientes
# 1        Aguascalientes           Aguascalientes
# 2        Aguascalientes           Aguascalientes
# 3        Aguascalientes           Aguascalientes
# 4        Aguascalientes           Aguascalientes
# ...                 ...                      ...
# 1521422          Puebla      Santiago Miahuatlán
# 1521423          Puebla      Santiago Miahuatlán
# 1521424          Puebla  Santo Tomás Hueyotlipan
# 1521425          Puebla  Santo Tomás Hueyotlipan
# 1521426          Puebla  Santo Tomás Hueyotlipan
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# index
# 0        23-PRONAFE-FERT-000510-S000-AS          AGUILAR          AGUILAR
# 1        23-PRONAFE-FERT-000339-S000-AS          AGUILAR           GARCIA
# 2        23-PRONAFE-FERT-000340-S000-AS          AGUILAR           GARCIA
# 3        23-PRONAFE-FERT-000511-S000-AS          AGUILAR          OROPEZA
# 4        23-PRONAFE-FERT-000676-S000-AS             ALBA          ESTRADA
# ...                                 ...              ...              ...
# 1521422  23-PRONAFE-FERT-075885-S000-PL          VAZQUEZ            NIETO
# 1521423  23-PRONAFE-FERT-075894-S000-PL          ZENTENO             CRUZ
# 1521424  23-PRONAFE-FERT-075946-S000-PL         GONZALEZ           ROMERO
# 1521425  23-PRONAFE-FERT-075947-S000-PL         GONZALEZ            ZAYAS
# 1521426  23-PRONAFE-FERT-075921-S000-PL            ZAYAS          RAMIREZ
#
#                 NOMBRE (S)  PAQUETE cve_ent
# index
# 0                  NICOLAS        2      01
# 1                   MANUEL        2      01
# 2                    PAULO        2      01
# 3                   MIGUEL        2      01
# 4        MARIA DEL ROSARIO        2      01
# ...                    ...      ...     ...
# 1521422        JOSE MANUEL        2      21
# 1521423        ANGEL DAVID        2      21
# 1521424             SABINA        1      21
# 1521425             MIRIAM        2      21
# 1521426          GUILLERMO        2      21
#
# [1521426 rows x 8 columns]

# %%
# Assuming 'df' is your original DataFrame with 'nom_ent' and 'cve_ent' columns
mapping_dict = inegi_df.set_index('NOM_MUN')['CVE_MUN'].to_dict()

# Create a new column 'cve_ent' in 'acreditados_df' DataFrame
acreditados_df['cve_mun'] = acreditados_df['MUNICIPIO'].map(mapping_dict)

# %%
acreditados_df
# Out:
#                  ESTADO                MUNICIPIO  \
# index
# 0        Aguascalientes           Aguascalientes
# 1        Aguascalientes           Aguascalientes
# 2        Aguascalientes           Aguascalientes
# 3        Aguascalientes           Aguascalientes
# 4        Aguascalientes           Aguascalientes
# ...                 ...                      ...
# 1521422          Puebla      Santiago Miahuatlán
# 1521423          Puebla      Santiago Miahuatlán
# 1521424          Puebla  Santo Tomás Hueyotlipan
# 1521425          Puebla  Santo Tomás Hueyotlipan
# 1521426          Puebla  Santo Tomás Hueyotlipan
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# index
# 0        23-PRONAFE-FERT-000510-S000-AS          AGUILAR          AGUILAR
# 1        23-PRONAFE-FERT-000339-S000-AS          AGUILAR           GARCIA
# 2        23-PRONAFE-FERT-000340-S000-AS          AGUILAR           GARCIA
# 3        23-PRONAFE-FERT-000511-S000-AS          AGUILAR          OROPEZA
# 4        23-PRONAFE-FERT-000676-S000-AS             ALBA          ESTRADA
# ...                                 ...              ...              ...
# 1521422  23-PRONAFE-FERT-075885-S000-PL          VAZQUEZ            NIETO
# 1521423  23-PRONAFE-FERT-075894-S000-PL          ZENTENO             CRUZ
# 1521424  23-PRONAFE-FERT-075946-S000-PL         GONZALEZ           ROMERO
# 1521425  23-PRONAFE-FERT-075947-S000-PL         GONZALEZ            ZAYAS
# 1521426  23-PRONAFE-FERT-075921-S000-PL            ZAYAS          RAMIREZ
#
#                 NOMBRE (S)  PAQUETE cve_ent cve_mun
# index
# 0                  NICOLAS        2      01     001
# 1                   MANUEL        2      01     001
# 2                    PAULO        2      01     001
# 3                   MIGUEL        2      01     001
# 4        MARIA DEL ROSARIO        2      01     001
# ...                    ...      ...     ...     ...
# 1521422        JOSE MANUEL        2      21     149
# 1521423        ANGEL DAVID        2      21     149
# 1521424             SABINA        1      21     151
# 1521425             MIRIAM        2      21     151
# 1521426          GUILLERMO        2      21     151
#
# [1521426 rows x 9 columns]

# %%
final_column_names = {
    'ESTADO': 'estado',
    'MUNICIPIO': 'municipio',
    'ACUSE': 'acuse',
    'APELLIDO PATERNO': 'apellido_paterno',
    'APELLIDO MATERNO': 'apellido_materno',
    'NOMBRE (S)': 'nombre_propio',
    'PAQUETE': 'paquete',    # Add more column names here
}

acreditados_df.rename(columns=final_column_names, inplace=True)

# %%
acreditados_df
# Out:
#                  estado                municipio  \
# index
# 0        Aguascalientes           Aguascalientes
# 1        Aguascalientes           Aguascalientes
# 2        Aguascalientes           Aguascalientes
# 3        Aguascalientes           Aguascalientes
# 4        Aguascalientes           Aguascalientes
# ...                 ...                      ...
# 1521422          Puebla      Santiago Miahuatlán
# 1521423          Puebla      Santiago Miahuatlán
# 1521424          Puebla  Santo Tomás Hueyotlipan
# 1521425          Puebla  Santo Tomás Hueyotlipan
# 1521426          Puebla  Santo Tomás Hueyotlipan
#
#                                   acuse apellido_paterno apellido_materno  \
# index
# 0        23-PRONAFE-FERT-000510-S000-AS          AGUILAR          AGUILAR
# 1        23-PRONAFE-FERT-000339-S000-AS          AGUILAR           GARCIA
# 2        23-PRONAFE-FERT-000340-S000-AS          AGUILAR           GARCIA
# 3        23-PRONAFE-FERT-000511-S000-AS          AGUILAR          OROPEZA
# 4        23-PRONAFE-FERT-000676-S000-AS             ALBA          ESTRADA
# ...                                 ...              ...              ...
# 1521422  23-PRONAFE-FERT-075885-S000-PL          VAZQUEZ            NIETO
# 1521423  23-PRONAFE-FERT-075894-S000-PL          ZENTENO             CRUZ
# 1521424  23-PRONAFE-FERT-075946-S000-PL         GONZALEZ           ROMERO
# 1521425  23-PRONAFE-FERT-075947-S000-PL         GONZALEZ            ZAYAS
# 1521426  23-PRONAFE-FERT-075921-S000-PL            ZAYAS          RAMIREZ
#
#              nombre_propio  paquete cve_ent cve_mun
# index
# 0                  NICOLAS        2      01     001
# 1                   MANUEL        2      01     001
# 2                    PAULO        2      01     001
# 3                   MIGUEL        2      01     001
# 4        MARIA DEL ROSARIO        2      01     001
# ...                    ...      ...     ...     ...
# 1521422        JOSE MANUEL        2      21     149
# 1521423        ANGEL DAVID        2      21     149
# 1521424             SABINA        1      21     151
# 1521425             MIRIAM        2      21     151
# 1521426          GUILLERMO        2      21     151
#
# [1521426 rows x 9 columns]

# %%
n_unique3 = acreditados_df['cve_mun'].nunique()

# %%
n_unique3
# Out:
# 560

# %%
n_unique4 = acreditados_df['municipio'].nunique()

# %%
n_unique4
# Out:
# 1684

# %%
acreditados_df['estado'] = acreditados_df['estado'].astype(str)
acreditados_df['municipio'] = acreditados_df['municipio'].astype(str)
acreditados_df['acuse'] = acreditados_df['acuse'].astype(str)
acreditados_df['apellido_paterno'] = acreditados_df['apellido_paterno'].astype(str)
acreditados_df['apellido_materno'] = acreditados_df['apellido_materno'].astype(str)
acreditados_df['nombre_propio'] = acreditados_df['nombre_propio'].astype(str)
acreditados_df['paquete'] = acreditados_df['paquete'].astype(int)
acreditados_df['cve_ent'] = acreditados_df['cve_ent'].astype(str)
acreditados_df['cve_mun'] = acreditados_df['cve_mun'].astype(str)

# %%
acreditados_df.dtypes
# Out:
# estado              object
# municipio           object
# acuse               object
# apellido_paterno    object
# apellido_materno    object
# nombre_propio       object
# paquete              int64
# cve_ent             object
# cve_mun             object
# dtype: object

# %%
acreditados_df.to_csv('../../data/productores_autorizados_final.csv')
