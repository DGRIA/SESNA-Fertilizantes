# %% [markdown]
# # Merge operation

# %% [markdown]
# In this notebook you will find the implementation to map the codes from inegi dataset to our current dataset.

# %%
import pandas as pd

# %%
dtype_dict = {
    'CVE_ENT': str,
    'CVE_MUN': str
}

inegi_df = pd.read_csv('../../data/dataset_inegi.csv', encoding='cp1252', dtype=dtype_dict)

# %%
inegi_df.columns
# Out:
# Index(['MAPA', 'Estatus', 'CVE_ENT', 'NOM_ENT', 'NOM_ABR', 'CVE_MUN',
#        'NOM_MUN', 'CVE_LOC', 'NOM_LOC', 'AMBITO', 'LATITUD', 'LONGITUD',
#        'LAT_DECIMAL', 'LON_DECIMAL', 'ALTITUD', 'CVE_CARTA', 'POB_TOTAL',
#        'POB_MASCULINA', 'POB_FEMENINA', 'TOTAL DE VIVIENDAS HABITADAS'],
#       dtype='object')

# %%
inegi_df.drop(columns=['MAPA'])
# Out:
#         Estatus CVE_ENT         NOM_ENT NOM_ABR CVE_MUN  \
# 0           NaN      01  Aguascalientes    Ags.     001
# 1           NaN      01  Aguascalientes    Ags.     001
# 2           NaN      01  Aguascalientes    Ags.     001
# 3           NaN      01  Aguascalientes    Ags.     001
# 4           NaN      01  Aguascalientes    Ags.     001
# ...         ...     ...             ...     ...     ...
# 299563      NaN      32       Zacatecas    Zac.     058
# 299564      NaN      32       Zacatecas    Zac.     058
# 299565      NaN      32       Zacatecas    Zac.     058
# 299566      NaN      32       Zacatecas    Zac.     058
# 299567      NaN      32       Zacatecas    Zac.     058
#
#                       NOM_MUN  CVE_LOC                 NOM_LOC AMBITO  \
# 0              Aguascalientes        1          Aguascalientes      U
# 1              Aguascalientes       94          Granja Adelita      R
# 2              Aguascalientes       96               Agua Azul      R
# 3              Aguascalientes      100           Rancho Alegre      R
# 4              Aguascalientes      102  Los Arbolitos [Rancho]      R
# ...                       ...      ...                     ...    ...
# 299563  Santa María de la Paz       39              San Isidro      R
# 299564  Santa María de la Paz       40                San José      R
# 299565  Santa María de la Paz       41   San Miguel Tepetitlán      R
# 299566  Santa María de la Paz       42              San Rafael      R
# 299567  Santa María de la Paz       43                Santa Fe      R
#
#                LATITUD         LONGITUD  LAT_DECIMAL  LON_DECIMAL  ALTITUD  \
# 0       21°52´47.362N"  102°17´45.768W"    21.879822  -102.296046     1878
# 1       21°52´18.749N"  102°22´24.710W"    21.871874  -102.373530     1901
# 2       21°53´01.522N"  102°21´25.639W"    21.883756  -102.357122     1861
# 3       21°51´16.556N"  102°22´21.884W"    21.854599  -102.372745     1879
# 4       21°46´48.650N"  102°21´26.261W"    21.780180  -102.357295     1861
# ...                ...              ...          ...          ...      ...
# 299563  21°29´11.130N"  103°20´14.164W"    21.486425  -103.337267     2036
# 299564  21°30´59.539N"  103°27´23.645W"    21.516539  -103.456568     1821
# 299565  21°30´15.168N"  103°20´09.356W"    21.504213  -103.335932     1977
# 299566  21°31´39.341N"  103°22´20.134W"    21.527594  -103.372259     2041
# 299567  21°31´44.371N"  103°23´06.343W"    21.528991  -103.385095     2021
#
#        CVE_CARTA POB_TOTAL POB_MASCULINA POB_FEMENINA  \
# 0         F13D19    863893        419168       444725
# 1         F13D18         5             *            *
# 2         F13D18        41            24           17
# 3         F13D18         0             0            0
# 4         F13D18         8             *            *
# ...          ...       ...           ...          ...
# 299563    F13D35         1             *            *
# 299564    F13D25         0             0            0
# 299565    F13D25        97            47           50
# 299566    F13D25         3             *            *
# 299567    F13D25         0             0            0
#
#        TOTAL DE VIVIENDAS HABITADAS
# 0                            246259
# 1                                 2
# 2                                12
# 3                                 0
# 4                                 2
# ...                             ...
# 299563                            1
# 299564                            0
# 299565                           31
# 299566                            1
# 299567                            0
#
# [299568 rows x 19 columns]

# %%
acreditados_df = pd.read_csv('../../data/productores_autorizados_fertilizantes.csv')

# %%
acreditados_df
# Out:
#                  ESTADO                 MUNICIPIO  \
# 0        Aguascalientes                  Tepezalá
# 1        Aguascalientes                  Asientos
# 2        Aguascalientes                  Asientos
# 3        Aguascalientes                  Asientos
# 4        Aguascalientes                  Asientos
# ...                 ...                       ...
# 1525715         Yucatán  San Lorenzo Axocomanitla
# 1525716         Yucatán  San Lorenzo Axocomanitla
# 1525717         Yucatán  San Lorenzo Axocomanitla
# 1525718         Yucatán  San Lorenzo Axocomanitla
# 1525719         Yucatán                    Sotuta
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 0        23-PRONAFE-FERT-006426-S000-AS             VERA         MARTINEZ
# 1        23-PRONAFE-FERT-001512-S000-AS          SANCHEZ           BERNAL
# 2        23-PRONAFE-FERT-001872-S000-AS          SANCHEZ           BERNAL
# 3        23-PRONAFE-FERT-001538-S000-AS          SANCHEZ           CAMPOS
# 4        23-PRONAFE-FERT-002131-S000-AS          SANCHEZ         CASTILLO
# ...                                 ...              ...              ...
# 1525715  23-PRONAFE-FERT-012460-S000-YN               EK              YAH
# 1525716  23-PRONAFE-FERT-012459-S000-YN               EK              YAH
# 1525717  23-PRONAFE-FERT-012455-S000-YN               EK            Y YAH
# 1525718  23-PRONAFE-FERT-012489-S000-YN           HUCHIM            MARIN
# 1525719  23-PRONAFE-FERT-020246-S000-YN       VALLADARES             POOT
#
#            NOMBRE (S)  PAQUETE
# 0             ROBERTO        2
# 1               LIDIA        1
# 2            VICTORIO        2
# 3                 EVA        2
# 4             ALFONSO        2
# ...               ...      ...
# 1525715          RAUL        2
# 1525716       MARCELO        2
# 1525717       BACILIO        2
# 1525718  FELIPE VIDAL        2
# 1525719  MANUEL JESUS        1
#
# [1525720 rows x 7 columns]

# %%
# Assuming 'df' is your original DataFrame with 'nom_ent' and 'cve_ent' columns
mapping_dict = inegi_df.set_index('NOM_ENT')['CVE_ENT'].to_dict()

# Create a new column 'cve_ent' in 'acreditados_df' DataFrame
acreditados_df['cve_ent'] = acreditados_df['ESTADO'].map(mapping_dict)

# %%
acreditados_df
# Out:
#                  ESTADO                 MUNICIPIO  \
# 0        Aguascalientes                  Tepezalá
# 1        Aguascalientes                  Asientos
# 2        Aguascalientes                  Asientos
# 3        Aguascalientes                  Asientos
# 4        Aguascalientes                  Asientos
# ...                 ...                       ...
# 1525715         Yucatán  San Lorenzo Axocomanitla
# 1525716         Yucatán  San Lorenzo Axocomanitla
# 1525717         Yucatán  San Lorenzo Axocomanitla
# 1525718         Yucatán  San Lorenzo Axocomanitla
# 1525719         Yucatán                    Sotuta
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 0        23-PRONAFE-FERT-006426-S000-AS             VERA         MARTINEZ
# 1        23-PRONAFE-FERT-001512-S000-AS          SANCHEZ           BERNAL
# 2        23-PRONAFE-FERT-001872-S000-AS          SANCHEZ           BERNAL
# 3        23-PRONAFE-FERT-001538-S000-AS          SANCHEZ           CAMPOS
# 4        23-PRONAFE-FERT-002131-S000-AS          SANCHEZ         CASTILLO
# ...                                 ...              ...              ...
# 1525715  23-PRONAFE-FERT-012460-S000-YN               EK              YAH
# 1525716  23-PRONAFE-FERT-012459-S000-YN               EK              YAH
# 1525717  23-PRONAFE-FERT-012455-S000-YN               EK            Y YAH
# 1525718  23-PRONAFE-FERT-012489-S000-YN           HUCHIM            MARIN
# 1525719  23-PRONAFE-FERT-020246-S000-YN       VALLADARES             POOT
#
#            NOMBRE (S)  PAQUETE cve_ent
# 0             ROBERTO        2      01
# 1               LIDIA        1      01
# 2            VICTORIO        2      01
# 3                 EVA        2      01
# 4             ALFONSO        2      01
# ...               ...      ...     ...
# 1525715          RAUL        2      31
# 1525716       MARCELO        2      31
# 1525717       BACILIO        2      31
# 1525718  FELIPE VIDAL        2      31
# 1525719  MANUEL JESUS        1      31
#
# [1525720 rows x 8 columns]

# %%
# Assuming 'df' is your original DataFrame with 'nom_ent' and 'cve_ent' columns
mapping_dict = inegi_df.set_index('NOM_MUN')['CVE_MUN'].to_dict()

# Create a new column 'cve_ent' in 'acreditados_df' DataFrame
acreditados_df['cve_mun'] = acreditados_df['MUNICIPIO'].map(mapping_dict)

# %%
acreditados_df
# Out:
#                  ESTADO                 MUNICIPIO  \
# 0        Aguascalientes                  Tepezalá
# 1        Aguascalientes                  Asientos
# 2        Aguascalientes                  Asientos
# 3        Aguascalientes                  Asientos
# 4        Aguascalientes                  Asientos
# ...                 ...                       ...
# 1525715         Yucatán  San Lorenzo Axocomanitla
# 1525716         Yucatán  San Lorenzo Axocomanitla
# 1525717         Yucatán  San Lorenzo Axocomanitla
# 1525718         Yucatán  San Lorenzo Axocomanitla
# 1525719         Yucatán                    Sotuta
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 0        23-PRONAFE-FERT-006426-S000-AS             VERA         MARTINEZ
# 1        23-PRONAFE-FERT-001512-S000-AS          SANCHEZ           BERNAL
# 2        23-PRONAFE-FERT-001872-S000-AS          SANCHEZ           BERNAL
# 3        23-PRONAFE-FERT-001538-S000-AS          SANCHEZ           CAMPOS
# 4        23-PRONAFE-FERT-002131-S000-AS          SANCHEZ         CASTILLO
# ...                                 ...              ...              ...
# 1525715  23-PRONAFE-FERT-012460-S000-YN               EK              YAH
# 1525716  23-PRONAFE-FERT-012459-S000-YN               EK              YAH
# 1525717  23-PRONAFE-FERT-012455-S000-YN               EK            Y YAH
# 1525718  23-PRONAFE-FERT-012489-S000-YN           HUCHIM            MARIN
# 1525719  23-PRONAFE-FERT-020246-S000-YN       VALLADARES             POOT
#
#            NOMBRE (S)  PAQUETE cve_ent cve_mun
# 0             ROBERTO        2      01     009
# 1               LIDIA        1      01     002
# 2            VICTORIO        2      01     002
# 3                 EVA        2      01     002
# 4             ALFONSO        2      01     002
# ...               ...      ...     ...     ...
# 1525715          RAUL        2      31     054
# 1525716       MARCELO        2      31     054
# 1525717       BACILIO        2      31     054
# 1525718  FELIPE VIDAL        2      31     054
# 1525719  MANUEL JESUS        1      31     069
#
# [1525720 rows x 9 columns]

# %%
final_column_names = {
    'ESTADO': 'estado',
    'MUNICIPIO': 'municipio',
    'ACUSE': 'acuse',
    'APELLIDO PATERNO': 'apellido_paterno',
    'APELLIDO MATERNO': 'apellido_materno',
    'NOMBRE (S)': 'nombre_propio',
    'PAQUETE': 'paquete',    # Add more column names here
}

acreditados_df.rename(columns=final_column_names, inplace=True)

# %%
acreditados_df
# Out:
#                  estado                 municipio  \
# 0        Aguascalientes                  Tepezalá
# 1        Aguascalientes                  Asientos
# 2        Aguascalientes                  Asientos
# 3        Aguascalientes                  Asientos
# 4        Aguascalientes                  Asientos
# ...                 ...                       ...
# 1525715         Yucatán  San Lorenzo Axocomanitla
# 1525716         Yucatán  San Lorenzo Axocomanitla
# 1525717         Yucatán  San Lorenzo Axocomanitla
# 1525718         Yucatán  San Lorenzo Axocomanitla
# 1525719         Yucatán                    Sotuta
#
#                                   acuse apellido_paterno apellido_materno  \
# 0        23-PRONAFE-FERT-006426-S000-AS             VERA         MARTINEZ
# 1        23-PRONAFE-FERT-001512-S000-AS          SANCHEZ           BERNAL
# 2        23-PRONAFE-FERT-001872-S000-AS          SANCHEZ           BERNAL
# 3        23-PRONAFE-FERT-001538-S000-AS          SANCHEZ           CAMPOS
# 4        23-PRONAFE-FERT-002131-S000-AS          SANCHEZ         CASTILLO
# ...                                 ...              ...              ...
# 1525715  23-PRONAFE-FERT-012460-S000-YN               EK              YAH
# 1525716  23-PRONAFE-FERT-012459-S000-YN               EK              YAH
# 1525717  23-PRONAFE-FERT-012455-S000-YN               EK            Y YAH
# 1525718  23-PRONAFE-FERT-012489-S000-YN           HUCHIM            MARIN
# 1525719  23-PRONAFE-FERT-020246-S000-YN       VALLADARES             POOT
#
#         nombre_propio  paquete cve_ent cve_mun
# 0             ROBERTO        2      01     009
# 1               LIDIA        1      01     002
# 2            VICTORIO        2      01     002
# 3                 EVA        2      01     002
# 4             ALFONSO        2      01     002
# ...               ...      ...     ...     ...
# 1525715          RAUL        2      31     054
# 1525716       MARCELO        2      31     054
# 1525717       BACILIO        2      31     054
# 1525718  FELIPE VIDAL        2      31     054
# 1525719  MANUEL JESUS        1      31     069
#
# [1525720 rows x 9 columns]

# %%
n_unique3 = acreditados_df['cve_mun'].nunique()

# %%
n_unique3
# Out:
# 560

# %%
n_unique4 = acreditados_df['municipio'].nunique()

# %%
n_unique4
# Out:
# 1684

# %%
acreditados_df['estado'] = acreditados_df['estado'].astype(str)
acreditados_df['municipio'] = acreditados_df['municipio'].astype(str)
acreditados_df['acuse'] = acreditados_df['acuse'].astype(str)
acreditados_df['apellido_paterno'] = acreditados_df['apellido_paterno'].astype(str)
acreditados_df['apellido_materno'] = acreditados_df['apellido_materno'].astype(str)
acreditados_df['nombre_propio'] = acreditados_df['nombre_propio'].astype(str)
acreditados_df['paquete'] = acreditados_df['paquete'].astype(int)
acreditados_df['cve_ent'] = acreditados_df['cve_ent'].astype(str)
acreditados_df['cve_mun'] = acreditados_df['cve_mun'].astype(str)

# %%
acreditados_df.dtypes
# Out:
# estado              object
# municipio           object
# acuse               object
# apellido_paterno    object
# apellido_materno    object
# nombre_propio       object
# paquete              int64
# cve_ent             object
# cve_mun             object
# dtype: object

# %%
acreditados_df.to_csv('../../data/productores_autorizados_final.csv', index=False)
