# %%
import pandas as pd

# %%
inegi_2019 = pd.read_csv('../../data/dataset_inegi_clean_2019.csv')
inegi_2020 = pd.read_csv('../../data/dataset_inegi_clean_2020.csv')
inegi_2021 = pd.read_csv('../../data/dataset_inegi_clean_2021.csv')
inegi_2022 = pd.read_csv('../../data/dataset_inegi_clean_2022.csv')

# %%
inegi_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300240 entries, 0 to 300239
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CVE_ENT            300240 non-null  int64
#  1   Entidad_inegi      300240 non-null  object
#  2   CVE_MUN            300240 non-null  int64
#  3   Municipio_inegi    300240 non-null  object
#  4   CVE_LOC            300240 non-null  int64
#  5   Localidad_inegi    300240 non-null  object
#  6   Entidad_c_inegi    300240 non-null  object
#  7   Municipio_c_inegi  300240 non-null  object
#  8   Localidad_c_inegi  300240 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 20.6+ MB

# %%
# Ordenar el DataFrame por Entidad_inegi, Municipio_inegi y Localidad_inegi
df_sorted = inegi_2019.sort_values(by=['Entidad_inegi', 'Municipio_inegi', 'Localidad_inegi'])

# Identificar duplicados basados en Entidad_inegi, Municipio_inegi y Localidad_inegi
duplicados = df_sorted[df_sorted.duplicated(subset=['Entidad_inegi', 'Municipio_inegi', 'Localidad_inegi'], keep=False)]
duplicados.head(20)
# Out:
#      CVE_ENT   Entidad_inegi  CVE_MUN Municipio_inegi  CVE_LOC  \
# 377        1  Aguascalientes        1  Aguascalientes     2054
# 529        1  Aguascalientes        1  Aguascalientes     2272
# 304        1  Aguascalientes        1  Aguascalientes     1116
# 328        1  Aguascalientes        1  Aguascalientes     1168
# 519        1  Aguascalientes        1  Aguascalientes     2261
# 604        1  Aguascalientes        1  Aguascalientes     2375
# 176        1  Aguascalientes        1  Aguascalientes      792
# 361        1  Aguascalientes        1  Aguascalientes     2035
# 215        1  Aguascalientes        1  Aguascalientes      918
# 369        1  Aguascalientes        1  Aguascalientes     2044
# 526        1  Aguascalientes        1  Aguascalientes     2269
# 581        1  Aguascalientes        1  Aguascalientes     2341
# 616        1  Aguascalientes        1  Aguascalientes     2389
# 140        1  Aguascalientes        1  Aguascalientes      637
# ...
