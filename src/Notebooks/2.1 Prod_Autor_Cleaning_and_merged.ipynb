# %% [markdown]
# # Data Cleaning Listado de Productores Autorizados

# %% [markdown]
# ## Autores
# - José Luis Delgado Dávara
# - Arturo Ortiz Aguilar
# - Beltrán Valle Gutiérrez-Cortines

# %%
import pandas as pd
import seaborn as sns
from thefuzz import fuzz
from thefuzz import process
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import re
import unidecode

# %%
def load_datasets(directory):
    # Get a list of all CSV files in the directory
    csv_files = glob.glob(os.path.join(directory, '*.csv'))

    dataframes = []
    for file in csv_files:
        try:
            # Try to read the CSV file with cp1252 encoding
            df = pd.read_csv(file, encoding='cp1252', index_col=0, skiprows=1)
        except UnicodeDecodeError:
            # If it fails, try to read the CSV file with utf-8 encoding
            df = pd.read_csv(file, encoding='utf-8', index_col=0, skiprows=1)
        
        # Print the columns of the current DataFrame
        print(f"Columns in {file}: {df.columns.tolist()}")
        
        dataframes.append(df)

    # Concatenate all DataFrames in the list
    merged_df = pd.concat(dataframes, ignore_index=True)

    return merged_df


def clean_text(text):
    """
    De esta manera tenemos el texto sin espacios blancos extra y sobre todo con todas las palabras con capitalización correcta.
    """
    if pd.isna(text):
        return text
    text = text.strip()  # Eliminate white spaces
    text = text.lower()  # Convert to lowercase
    text = unidecode.unidecode(text)  # Remove accents
    text = re.sub('-.*-', '', text)
    text = re.sub('\s+', ' ', text)  # Eliminate extra white spaces
    text = re.sub('^\s+|\s+?$', '', text)  # Eliminate spaces at the beginning and end
    return text

# %% [markdown]
# # 1. Lectura de los datos

# %% [markdown]
# Lectura del dataset del INEGI

# %%
path_dataset_inegi = '../../data/inegi/dataset_inegi.csv'
dataset_inegi = pd.read_csv(path_dataset_inegi, encoding='cp1252', dtype={'CVE_ENT': str, 'CVE_MUN': str})

# %% [markdown]
# Lectura del listado de productores autorizados

# %%
listado_productores = load_datasets('../../data/productores_autorizados')
# Out:
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_txl_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_listado_autori_fertilizantes_23_bc.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_ags_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_tbs.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_2do_listado_autori_fertilizantes_23_gro_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_hgo.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_tbs_convo_2.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_zac.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_2do_listado_autori_fertilizantes_23_pbl_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_cmp_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_cdmx_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_chp_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_hgo_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_txl.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_tml.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_qnro_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_nvoingreso_listado_autori_fertilizantes_23_txl.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10']
# Columns in ../../data/productores_autorizados/anexo_unico_nvoingreso_listado_autori_fertilizantes_23_bc.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_col_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_3er_listado_autori_fertilizantes_23_dgo.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_chh.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_2do_listado_autori_fertilizantes_23_jal_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_nay.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_yct_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_mor_convo_2.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_listado_autori_fertilizantes_23_bcs.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_oax_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_3er_listado_autori_fertilizantes_23_oax.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_mor_convo_2.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_son.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_dgo_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_slp.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mch_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_3er_listado_autori_fertilizantes_23_cmp.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_nvo.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_1er_listado_autori_fertilizantes_23_son.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_vrz_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_qur.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_cdmx.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_jal_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_gro_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_1er_listado_autori_fertilizantes_23_coa.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mex_convo_2.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_nvoingreso_listado_autori_fertilizantes_23_qur.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mor_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mex_convo_3.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_3er_listado_autori_fertilizantes_23_vrz.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mex_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_cmp_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_3er_listado_autori_fertilizantes_23_chi.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_3er_listado_autori_fertilizantes_23_yuc.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_qro_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_nvoingreso_listado_autori_fertilizantes_23_son.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_i_1er_listado_autori_fertilizantes_23_pbl_convo_1.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']
# Columns in ../../data/productores_autorizados/anexo_unico_nvoingreso_listado_autori_fertilizantes_23_bcs.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10']
# Columns in ../../data/productores_autorizados/anexo_unico_2do_listado_autori_fertilizantes_23_coa.csv: ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO', 'NOMBRE (S)', 'PAQUETE']

# %% [markdown]
# # 2. Limpieza de los datos

# %% [markdown]
# ## 2.1 INEGI

# %%
# Revisamos las columnas del dataset
dataset_inegi.columns
# Out:
# Index(['MAPA', 'Estatus', 'CVE_ENT', 'NOM_ENT', 'NOM_ABR', 'CVE_MUN',
#        'NOM_MUN', 'CVE_LOC', 'NOM_LOC', 'AMBITO', 'LATITUD', 'LONGITUD',
#        'LAT_DECIMAL', 'LON_DECIMAL', 'ALTITUD', 'CVE_CARTA', 'POB_TOTAL',
#        'POB_MASCULINA', 'POB_FEMENINA', 'TOTAL DE VIVIENDAS HABITADAS'],
#       dtype='object')

# %%
# Revisamos las primeras filas del dataset
dataset_inegi.head()
# Out:
#        MAPA  Estatus CVE_ENT         NOM_ENT NOM_ABR CVE_MUN         NOM_MUN  \
# 0  10010001      NaN      01  Aguascalientes    Ags.     001  Aguascalientes
# 1  10010094      NaN      01  Aguascalientes    Ags.     001  Aguascalientes
# 2  10010096      NaN      01  Aguascalientes    Ags.     001  Aguascalientes
# 3  10010100      NaN      01  Aguascalientes    Ags.     001  Aguascalientes
# 4  10010102      NaN      01  Aguascalientes    Ags.     001  Aguascalientes
#
#    CVE_LOC                 NOM_LOC AMBITO         LATITUD         LONGITUD  \
# 0        1          Aguascalientes      U  21°52´47.362N"  102°17´45.768W"
# 1       94          Granja Adelita      R  21°52´18.749N"  102°22´24.710W"
# 2       96               Agua Azul      R  21°53´01.522N"  102°21´25.639W"
# 3      100           Rancho Alegre      R  21°51´16.556N"  102°22´21.884W"
# 4      102  Los Arbolitos [Rancho]      R  21°46´48.650N"  102°21´26.261W"
#
#    LAT_DECIMAL  LON_DECIMAL  ALTITUD CVE_CARTA POB_TOTAL POB_MASCULINA  \
# 0    21.879822  -102.296046     1878    F13D19    863893        419168
# 1    21.871874  -102.373530     1901    F13D18         5             *
# 2    21.883756  -102.357122     1861    F13D18        41            24
# 3    21.854599  -102.372745     1879    F13D18         0             0
# 4    21.780180  -102.357295     1861    F13D18         8             *
#
#   POB_FEMENINA TOTAL DE VIVIENDAS HABITADAS
# 0       444725                       246259
# 1            *                            2
# 2           17                           12
# 3            0                            0
# 4            *                            2

# %%
# Eliminamos las columnas que no son de interés
COLUMNS_TO_DROP = ['MAPA', 'Estatus', 'NOM_ABR', 'CVE_LOC', 'NOM_LOC', 'AMBITO', 'LATITUD', 'LONGITUD',
                   'LAT_DECIMAL', 'LON_DECIMAL', 'ALTITUD', 'CVE_CARTA', 'POB_TOTAL',
                   'POB_MASCULINA', 'POB_FEMENINA', 'TOTAL DE VIVIENDAS HABITADAS']
dataset_inegi = dataset_inegi.drop(COLUMNS_TO_DROP, axis=1)

# %%
# Las claves de entidad y municipio serán tratadas numéricamente en la limpieza aunque posteriormente se les asignará el tipo de cadena de texto para tener el estándar.
dataset_inegi.dtypes
# Out:
# CVE_ENT    object
# NOM_ENT    object
# CVE_MUN    object
# NOM_MUN    object
# dtype: object

# %%
# Revisamos la cantidad de filas y columnas del dataset
print("Shape of dataset_inegi: ", dataset_inegi.shape)

dataset_inegi_clean = dataset_inegi.drop_duplicates()
print("Shape of dataset_inegi_clean: ", dataset_inegi_clean.shape)
# Out:
# Shape of dataset_inegi:  (299568, 4)
# Shape of dataset_inegi_clean:  (2476, 4)

# %% [markdown]
# A partir de aquí seguimos trabajando con el listado de Estados y Municipios limpio de Inegi (sin repetir) "dataset_inegi_clean".

# %%
# Revisamos las primeras filas del dataset con las columnas seleccionadas
dataset_inegi_clean.head()
# Out:
#      CVE_ENT         NOM_ENT CVE_MUN         NOM_MUN
# 0         01  Aguascalientes     001  Aguascalientes
# 708       01  Aguascalientes     002        Asientos
# 945       01  Aguascalientes     003        Calvillo
# 1237      01  Aguascalientes     004           Cosío
# 1330      01  Aguascalientes     005     Jesús María

# %%
# Revisamos las últimas filas del dataset con las columnas seleccionadas
dataset_inegi_clean.tail()
# Out:
#        CVE_ENT    NOM_ENT CVE_MUN                NOM_MUN
# 299150      32  Zacatecas     054          Villa Hidalgo
# 299211      32  Zacatecas     055             Villanueva
# 299363      32  Zacatecas     056              Zacatecas
# 299484      32  Zacatecas     057               Trancoso
# 299526      32  Zacatecas     058  Santa María de la Paz

# %%
dataset_inegi_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2476 entries, 0 to 299526
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CVE_ENT  2476 non-null   object
#  1   NOM_ENT  2476 non-null   object
#  2   CVE_MUN  2476 non-null   object
#  3   NOM_MUN  2476 non-null   object
# dtypes: object(4)
# memory usage: 96.7+ KB

# %%
print("Los valores únicos en cada columna son:\n", dataset_inegi_clean.nunique())
# Out:
# Los valores únicos en cada columna son:
#  CVE_ENT      32
# NOM_ENT      32
# CVE_MUN     570
# NOM_MUN    2332
# dtype: int64

# %%
# Creamos una columna con la clave única por municipio

dataset_inegi_clean['CVE_MUN_Unique'] = dataset_inegi_clean['CVE_ENT'].astype(str) + '-' + dataset_inegi_clean[
    'CVE_MUN'].astype(str)

dataset_inegi_clean.head()
# Out:
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_79637/2609109509.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_inegi_clean['CVE_MUN_Unique'] = dataset_inegi_clean['CVE_ENT'].astype(str) + '-' + dataset_inegi_clean[
#      CVE_ENT         NOM_ENT CVE_MUN         NOM_MUN CVE_MUN_Unique
# 0         01  Aguascalientes     001  Aguascalientes         01-001
# 708       01  Aguascalientes     002        Asientos         01-002
# 945       01  Aguascalientes     003        Calvillo         01-003
# 1237      01  Aguascalientes     004           Cosío         01-004
# 1330      01  Aguascalientes     005     Jesús María         01-005

# %%
dataset_inegi_clean.tail()
# Out:
#        CVE_ENT    NOM_ENT CVE_MUN                NOM_MUN CVE_MUN_Unique
# 299150      32  Zacatecas     054          Villa Hidalgo         32-054
# 299211      32  Zacatecas     055             Villanueva         32-055
# 299363      32  Zacatecas     056              Zacatecas         32-056
# 299484      32  Zacatecas     057               Trancoso         32-057
# 299526      32  Zacatecas     058  Santa María de la Paz         32-058

# %% [markdown]
# ### 2.1.1 Estandarización de nombre de municipios
#
# Con el fin de poder hacer un merge bajo los mismos nombres, hacemos una limpieza de los datos.

# %%
# Estandarizamos la limpieza de los datos
dataset_inegi_clean['NOM_ENT_Clean'] = dataset_inegi_clean['NOM_ENT'].apply(clean_text)
dataset_inegi_clean['NOM_MUN_Clean'] = dataset_inegi_clean['NOM_MUN'].apply(clean_text)
# Out:
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_79637/1220250931.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_inegi_clean['NOM_ENT_Clean'] = dataset_inegi_clean['NOM_ENT'].apply(clean_text)
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_79637/1220250931.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_inegi_clean['NOM_MUN_Clean'] = dataset_inegi_clean['NOM_MUN'].apply(clean_text)

# %%
dataset_inegi_clean
# Out:
#        CVE_ENT         NOM_ENT CVE_MUN                NOM_MUN CVE_MUN_Unique  \
# 0           01  Aguascalientes     001         Aguascalientes         01-001
# 708         01  Aguascalientes     002               Asientos         01-002
# 945         01  Aguascalientes     003               Calvillo         01-003
# 1237        01  Aguascalientes     004                  Cosío         01-004
# 1330        01  Aguascalientes     005            Jesús María         01-005
# ...        ...             ...     ...                    ...            ...
# 299150      32       Zacatecas     054          Villa Hidalgo         32-054
# 299211      32       Zacatecas     055             Villanueva         32-055
# 299363      32       Zacatecas     056              Zacatecas         32-056
# 299484      32       Zacatecas     057               Trancoso         32-057
# 299526      32       Zacatecas     058  Santa María de la Paz         32-058
#
#          NOM_ENT_Clean          NOM_MUN_Clean
# 0       aguascalientes         aguascalientes
# 708     aguascalientes               asientos
# 945     aguascalientes               calvillo
# 1237    aguascalientes                  cosio
# 1330    aguascalientes            jesus maria
# ...                ...                    ...
# 299150       zacatecas          villa hidalgo
# 299211       zacatecas             villanueva
# 299363       zacatecas              zacatecas
# 299484       zacatecas               trancoso
# 299526       zacatecas  santa maria de la paz
#
# [2476 rows x 7 columns]

# %%
dataset_inegi_clean.shape
# Out:
# (2476, 7)

# %% [markdown]
# ## 2.2 Listado de Productores Autorizados

# %%
listado_productores.columns
# Out:
# Index(['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO',
#        'NOMBRE (S)', 'PAQUETE', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
listado_productores = listado_productores.drop(columns=['Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'])

# %%
listado_productores.head()
# Out:
#      ESTADO                     MUNICIPIO                           ACUSE  \
# 0  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000018-S000-TL
# 1  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000016-S000-TL
# 2  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000005-S000-TL
# 3  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000006-S000-TL
# 4  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000007-S000-TL
#
#   APELLIDO PATERNO APELLIDO MATERNO          NOMBRE (S)  PAQUETE
# 0           AGUILA             LIMA          J. EUGENIO        2
# 1            CORTE         ESPINOZA  MA. PETRA APOLONIA        2
# 2            CORTE           PICHON              TERESA        2
# 3      CUAHTEPITZI             LUNA           FLORENCIO        2
# 4      CUAHTEPITZI          SANCHEZ   JOSE SIMON MARTIN        2

# %%
# Mostramos el tipo de dato de cada columna
listado_productores.dtypes
listado_productores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628170 entries, 0 to 1628169
# Data columns (total 7 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   ESTADO            1628170 non-null  object
#  1   MUNICIPIO         1552658 non-null  object
#  2   ACUSE             1628170 non-null  object
#  3   APELLIDO PATERNO  1623876 non-null  object
#  4   APELLIDO MATERNO  1598998 non-null  object
#  5   NOMBRE (S)        1623877 non-null  object
#  6   PAQUETE           1628170 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 87.0+ MB

# %%
# Observamos los valores únicos y la cantidad de cada columna, ordenados
COLUMNS_TO_VIEW = ['ESTADO', 'MUNICIPIO', 'PAQUETE']
for column in COLUMNS_TO_VIEW:
    unique_values = listado_productores[column].unique()
    if unique_values.dtype == 'object':
        unique_values = unique_values.astype(str)
        unique_values.sort()
    if len(unique_values) <= 1000:
        print(
            f"\n{column}\nCantidad de valores unicos {len(unique_values)}. Valores únicos en la columna {column}: {unique_values}")
    else:
        print(f"\nCantidad de valores únicos en {column}: {len(unique_values)}")
        print(f"Valores únicos en la columna {column}:")
        for value in unique_values:
            print(value)
# Out:
# ESTADO
# Cantidad de valores unicos 33. Valores únicos en la columna ESTADO: ['AGUASCALIENTES' 'BAJA CALIFORNIA' 'BAJA CALIFORNIA SUR' 'CAMPECHE'
#  'CHIAPAS' 'CHIHUAHUA' 'CIUDAD DE MEXICO' 'COAHUILA'
#  'COAHUILA DE ZARAGOZA' 'COLIMA' 'DURANGO' 'GUERRERO' 'HIDALGO' 'JALISCO'
#  'MEXICO' 'MICHOACAN DE OCAMPO' 'MORELOS' 'MÉXICO' 'NAYARIT' 'NUEVO LEON'
#  'OAXACA' 'PUEBLA' 'QUERETARO DE ARTEAGA' 'QUINTANA ROO' 'SAN LUIS POTOSI'
#  'SONORA' 'TABASCO' 'TAMAULIPAS' 'TLAXCALA' 'VERACRUZ'
#  'VERACRUZ DE IGNACIO DE LA LLAVE' 'YUCATAN' 'ZACATECAS']
#
# Cantidad de valores únicos en MUNICIPIO: 2146
# Valores únicos en la columna MUNICIPIO:
# ABALA
# ABASOLO
# ABEJONES
# ACACOYAGUA
# ACAJETE
# ACALA
# ACAMBAY
# ACANCEH
# ACAPETAHUA
# ACAPONETA
# ACAPULCO DE JUAREZ
# ACATENO
# ACATEPEC
# ACATIC
# ACATLAN
# ACATLAN DE JUAREZ
# ACATLAN DE PEREZ FIGUEROA
# ACATZINGO
# ACAXOCHITLAN
# ACAYUCAN
# ACOLMAN
# ACONCHI
# ACTEOPAN
# ACTOPAN
# ACUAMANALA DE MIGUEL HIDALGO
# ACUITZIO
# ACULCO
# ACUÑA
# AGUA BLANCA DE ITURBIDE
# AGUA DULCE
# AGUA PRIETA
# AGUASCALIENTES
# AGUILILLA
# ZIRACUARETIRO
# ZIRANDARO
# ZITACUARO
# ZITLALA
# ZITLALTEPEC DE TRINIDAD SANCHEZ SANTOS
# ZONGOLICA
# ZONGOZOTLA
# ZONTECOMATLAN DE LOPEZ Y FUENTES
# ZOQUIAPAN
# ZOQUITLAN
# ZOZOCOLCO DE HIDALGO
# ZUMPAHUACAN
# ZUMPANGO
# nan
#
# PAQUETE
# Cantidad de valores unicos 2. Valores únicos en la columna PAQUETE: [2 1]

# %%
municipio_counts = listado_productores['MUNICIPIO'].value_counts().reset_index()
municipio_counts.columns = ['MUNICIPIO', 'COUNT']
print(municipio_counts)
# Out:
#                  MUNICIPIO  COUNT
# 0           LAS MARGARITAS  21135
# 1      VENUSTIANO CARRANZA  16991
# 2       CHILAPA DE ALVAREZ  16484
# 3                 ACATEPEC  13163
# 4     AYUTLA DE LOS LIBRES  13160
# ...                    ...    ...
# 2140    CARLOS A. CARRILLO      1
# 2141               ATZACAN      1
# 2142       ANGEL R. CABADA      1
# 2143              ALVARADO      1
# 2144                  NAVA      1
#
# [2145 rows x 2 columns]

# %% [markdown]
# ¿Qué ESTADOS tienen algún municipio NULL?

# %%
municipios_null = listado_productores[listado_productores['MUNICIPIO'].isnull()]

# ¿Qué ESTADOS tienen algún municipio Null?
print(municipios_null['ESTADO'].unique())
# Out:
# ['VERACRUZ DE IGNACIO DE LA LLAVE']

# %%
# Filas duplicadas y filas únicas
duplicated_rows_productores = listado_productores.duplicated()
number_of_duplicated_rows_productores = duplicated_rows_productores.sum()
print(f"El número de filas duplicadas es: {number_of_duplicated_rows_productores}")
print(f"El número de filas únicas es: {listado_productores.shape[0] - number_of_duplicated_rows_productores}")
# Out:
# El número de filas duplicadas es: 1018
# El número de filas únicas es: 1627152

# %%
duplicated_rows = listado_productores[listado_productores.duplicated()]

# Imprimir las filas duplicadas
print(duplicated_rows)
# Out:
#            ESTADO MUNICIPIO                           ACUSE APELLIDO PATERNO  \
# 806221   CAMPECHE  CALAKMUL  23-PRONAFE-FERT-031246-S000-CC          ALEGRIA
# 806222   CAMPECHE  CALAKMUL  23-PRONAFE-FERT-031212-S000-CC          ALVAREZ
# 806223   CAMPECHE  CALAKMUL  23-PRONAFE-FERT-031229-S000-CC          ALVAREZ
# 806224   CAMPECHE  CALAKMUL  23-PRONAFE-FERT-031245-S000-CC           ALVARO
# 806225   CAMPECHE  CALAKMUL  23-PRONAFE-FERT-031201-S000-CC            ARCOS
# ...           ...       ...                             ...              ...
# 1496891  CAMPECHE  PALIZADA  23-PRONAFE-FERT-023316-S000-CC             DIAZ
# 1496918  CAMPECHE  PALIZADA  23-PRONAFE-FERT-023342-S000-CC            GOMEZ
# 1497006  CAMPECHE  PALIZADA  23-PRONAFE-FERT-023429-S000-CC           ROSADO
# 1497051  CAMPECHE    TENABO  23-PRONAFE-FERT-023476-S000-CC            AVILA
# 1497161  CAMPECHE    TENABO  23-PRONAFE-FERT-023581-S000-CC           CAUICH
#
#         APELLIDO MATERNO         NOMBRE (S)  PAQUETE
# 806221            MEDINA  AVILENNE SKARLETH        2
# 806222           JIMENEZ         CANDELARIA        2
# 806223             LOPEZ               ENOC        2
# 806224             LOPEZ       LOYDA EUNICE        2
# 806225              CRUZ              PEDRO        2
# ...                  ...                ...      ...
# 1496891            ARCOS            ABRAHAM        2
# 1496918             CHAN          NETZAHUAL        2
# 1497006          MENDOZA        ENCARNACION        2
# 1497051           ALAVEZ        LUIS FELIPE        2
# 1497161               UC     MARIA EDUVIGES        2
#
# [1018 rows x 7 columns]

# %%
listado_productores.drop_duplicates(inplace=True)

# %% [markdown]
# No hay filas completas duplicadas.

# %%
# Valores nulos
listado_productores.isna().sum()
# Out:
# ESTADO                  0
# MUNICIPIO           75512
# ACUSE                   0
# APELLIDO PATERNO     4294
# APELLIDO MATERNO    29168
# NOMBRE (S)           4293
# PAQUETE                 0
# dtype: int64

# %% [markdown]
# Existen 75512 filas con el municipio nulo.
# Y muchas filas con nombre y apellidos vacíos.

# %%
# Analicemos dónde los municipios están vacíos
listado_productores[(listado_productores['MUNICIPIO'].isna())]
# Out:
#                                  ESTADO MUNICIPIO  \
# 810170  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 810171  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 810172  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 810173  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 810174  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# ...                                 ...       ...
# 885677  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 885678  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 885679  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 885680  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 885681  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
#
#                                  ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 810170  23-PRONAFE-FERT-000001-S000-VZ           ABURTO          ALARCON
# 810171  23-PRONAFE-FERT-000002-S000-VZ           ABURTO          ALARCON
# 810172  23-PRONAFE-FERT-000003-S000-VZ           ABURTO         MARTINEZ
# 810173  23-PRONAFE-FERT-000004-S000-VZ           ABURTO          MORALES
# 810174  23-PRONAFE-FERT-000005-S000-VZ          ALARCON           GUZMAN
# ...                                ...              ...              ...
# 885677  23-PRONAFE-FERT-081776-S000-VZ            REYES        HERNANDEZ
# 885678  23-PRONAFE-FERT-081842-S000-VZ         SANTIAGO        SARMIENTO
# 885679  23-PRONAFE-FERT-081843-S000-VZ          VAZQUEZ            GAONA
# 885680  23-PRONAFE-FERT-081845-S000-VZ             VEGA        RODRIGUEZ
# 885681  23-PRONAFE-FERT-081846-S000-VZ          VICENTE         DE GAONA
#
#               NOMBRE (S)  PAQUETE
# 810170         ASCENCION        1
# 810171            GENARO        1
# 810172  MARIA DEL CARMEN        2
# 810173      MIGUEL ANGEL        2
# 810174          MARCIANO        2
# ...                  ...      ...
# 885677           RUTILIO        1
# 885678          LEOBARDO        2
# 885679              JOSE        2
# 885680              JUAN        1
# 885681              JOSE        2
#
# [75512 rows x 7 columns]

# %% [markdown]
# Todas las filas con municipios vacíos vienen del estado de Veracruz de Ignacio de la Llave.

# %%
listado_productores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1627152 entries, 0 to 1628169
# Data columns (total 7 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   ESTADO            1627152 non-null  object
#  1   MUNICIPIO         1551640 non-null  object
#  2   ACUSE             1627152 non-null  object
#  3   APELLIDO PATERNO  1622858 non-null  object
#  4   APELLIDO MATERNO  1597984 non-null  object
#  5   NOMBRE (S)        1622859 non-null  object
#  6   PAQUETE           1627152 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 99.3+ MB

# %% [markdown]
# ### 2.1.1 Estandarización de nombre de municipios
#
# Con el fin de poder hacer un merge bajo los mismos nombres, hacemos una limpieza de los nombres de municipios en un dataset más ligero llamado **Estados_productores**.

# %%
# Seleccionar solo las dos primeras columnas
Estados_productores = listado_productores[['ESTADO', 'MUNICIPIO']]

# Obtener las filas únicas
Estados_productores = Estados_productores.drop_duplicates()

# %%
Estados_productores.shape
# Out:
# (2415, 2)

# %%
# Estandarizamos la limpieza de los datos
Estados_productores['ESTADO_Clean'] = Estados_productores['ESTADO'].apply(clean_text)
Estados_productores['MUNICIPIO_Clean'] = Estados_productores['MUNICIPIO'].apply(clean_text)

# %% [markdown]
# Creamos columna clave

# %%
# Primero creemos una columna clave en cada dataset -> Estados productores

Estados_productores["ESTADO_Clean"] = Estados_productores["ESTADO_Clean"].astype(str)
Estados_productores["MUNICIPIO_Clean"] = Estados_productores["MUNICIPIO_Clean"].astype(str)

Estados_productores["KEY_prod"] = Estados_productores["ESTADO_Clean"] + "-" + Estados_productores["MUNICIPIO_Clean"]

# %%
Estados_productores.shape
# Out:
# (2415, 5)

# %% [markdown]
# # 3. Diccionario de los datasets de INEGI Y PRODUCTORES AUTORIZADOS
#
# A este punto llegamos con 3 datasets:
#     1. dataset_inegi_clean: municipios y estados de INEGI con los nombres estandarizados
#     2. Productores_Autorizados: listado de productores autorizados con municipios y estados estandarizados
#     3. Estados_productores: Municipios y Estados únicos que aparecen en el listado de Productores Autorizados, sin el formato INEGI.
#
# El objetivo de esta sección es crear un diccionario de códigos según INEGI para los municipios Estados_productores. Para ello haremos un Left join entre Estados_productores y dataset_inegi_clean.

# %% [markdown]
# ### 3.1 Left join

# %%
# Primero creemos una columna clave en cada dataset -> INEGI

dataset_inegi_clean["NOM_ENT_Clean"] = dataset_inegi_clean["NOM_ENT_Clean"].astype(str)
dataset_inegi_clean["NOM_MUN_Clean"] = dataset_inegi_clean["NOM_MUN_Clean"].astype(str)

dataset_inegi_clean["KEY_inegi"] = dataset_inegi_clean["NOM_ENT_Clean"] + "-" + dataset_inegi_clean["NOM_MUN_Clean"]
# Out:
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_79637/1010743891.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_inegi_clean["NOM_ENT_Clean"] = dataset_inegi_clean["NOM_ENT_Clean"].astype(str)
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_79637/1010743891.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_inegi_clean["NOM_MUN_Clean"] = dataset_inegi_clean["NOM_MUN_Clean"].astype(str)
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_79637/1010743891.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_inegi_clean["KEY_inegi"] = dataset_inegi_clean["NOM_ENT_Clean"] + "-" + dataset_inegi_clean["NOM_MUN_Clean"]

# %%
dataset_inegi_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2476 entries, 0 to 299526
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CVE_ENT         2476 non-null   object
#  1   NOM_ENT         2476 non-null   object
#  2   CVE_MUN         2476 non-null   object
#  3   NOM_MUN         2476 non-null   object
#  4   CVE_MUN_Unique  2476 non-null   object
#  5   NOM_ENT_Clean   2476 non-null   object
#  6   NOM_MUN_Clean   2476 non-null   object
#  7   KEY_inegi       2476 non-null   object
# dtypes: object(8)
# memory usage: 174.1+ KB

# %%
Estados_productores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2415 entries, 0 to 1628165
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ESTADO           2415 non-null   object
#  1   MUNICIPIO        2414 non-null   object
#  2   ESTADO_Clean     2415 non-null   object
#  3   MUNICIPIO_Clean  2415 non-null   object
#  4   KEY_prod         2415 non-null   object
# dtypes: object(5)
# memory usage: 113.2+ KB

# %%
Estados_productores = Estados_productores.drop(['ESTADO', 'MUNICIPIO'], axis=1)
Estados_productores = Estados_productores.drop_duplicates()
Estados_productores.shape
# Out:
# (2289, 3)

# %% [markdown]
# Comprobamos que la columna KEY es realmente clave.

# %%
Estados_productores['KEY_prod'].nunique()
# Out:
# 2289

# %%
# Crear una función para encontrar la mejor coincidencia difusa con límites entre 90 y 100 de coincidencia
def fuzzy_merge(df_inegi, df_prod, key1, key2, threshold=96, limit=1):
    """
    df_inegi: DataFrame de la izquierda (el DataFrame principal)
    df_prod: DataFrame de la derecha (el DataFrame con el que se quiere hacer el join)
    key1: Columna de la clave en df_inegi
    key2: Columna de la clave en df_prod
    threshold: Umbral de coincidencia difusa
    limit: Número de coincidencias a encontrar
    """
    s = df_prod[key2].tolist()

    # Encontrar las mejores coincidencias para cada clave en df_inegi
    matches = df_inegi[key1].apply(lambda x: process.extractOne(x, s, score_cutoff=threshold))

    # Crear una columna con las mejores coincidencias
    df_inegi['best_match'] = [match[0] if match else None for match in matches]
    df_inegi['match_score'] = [match[1] if match else None for match in matches]

    # Hacer el merge con las mejores coincidencias
    df_merged = pd.merge(df_inegi, df_prod, left_on='best_match', right_on=key2, how='inner',
                         suffixes=('_inegi', '_prod'))
    
    return df_merged

# %%
# Aplicar la función de coincidencia difusa
diccionario = fuzzy_merge(dataset_inegi_clean, Estados_productores, 'KEY_inegi', 'KEY_prod')
diccionario.drop_duplicates(subset=['KEY_inegi'], inplace=True)

# Mostrar el resultado
diccionario.columns
# Out:
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_79637/1524280736.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inegi['best_match'] = [match[0] if match else None for match in matches]
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_79637/1524280736.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_inegi['match_score'] = [match[1] if match else None for match in matches]
# Index(['CVE_ENT', 'NOM_ENT', 'CVE_MUN', 'NOM_MUN', 'CVE_MUN_Unique',
#        'NOM_ENT_Clean', 'NOM_MUN_Clean', 'KEY_inegi', 'best_match',
#        'match_score', 'ESTADO_Clean', 'MUNICIPIO_Clean', 'KEY_prod'],
#       dtype='object')

# %%
diccionario.head()
# Out:
#   CVE_ENT         NOM_ENT CVE_MUN         NOM_MUN CVE_MUN_Unique  \
# 0      01  Aguascalientes     001  Aguascalientes         01-001
# 1      01  Aguascalientes     002        Asientos         01-002
# 2      01  Aguascalientes     003        Calvillo         01-003
# 3      01  Aguascalientes     004           Cosío         01-004
# 4      01  Aguascalientes     005     Jesús María         01-005
#
#     NOM_ENT_Clean   NOM_MUN_Clean                      KEY_inegi  \
# 0  aguascalientes  aguascalientes  aguascalientes-aguascalientes
# 1  aguascalientes        asientos        aguascalientes-asientos
# 2  aguascalientes        calvillo        aguascalientes-calvillo
# 3  aguascalientes           cosio           aguascalientes-cosio
# 4  aguascalientes     jesus maria     aguascalientes-jesus maria
#
#                       best_match  match_score    ESTADO_Clean MUNICIPIO_Clean  \
# 0  aguascalientes-aguascalientes        100.0  aguascalientes  aguascalientes
# 1        aguascalientes-asientos        100.0  aguascalientes        asientos
# 2        aguascalientes-calvillo        100.0  aguascalientes        calvillo
# 3           aguascalientes-cosio        100.0  aguascalientes           cosio
# 4     aguascalientes-jesus maria        100.0  aguascalientes     jesus maria
#
#                         KEY_prod
# 0  aguascalientes-aguascalientes
# 1        aguascalientes-asientos
# 2        aguascalientes-calvillo
# 3           aguascalientes-cosio
# 4     aguascalientes-jesus maria

# %%
diccionario.to_csv('../../data/productores_autorizados/diccionarios_E1/diccionario_prod.csv', index=False)

# %% [markdown]
# ## 3.2 Productores Autorizados
#
# Esta sección se encarga de completar el listado original de Productores Autorizados con los nombre corregido de INEGI usando el diccionario.

# %%
# Crear una variable KEY en listado de productores y el diccionario para hacer el join
listado_productores['ESTADO_Clean'] = listado_productores['ESTADO'].apply(clean_text)
listado_productores['MUNICIPIO_Clean'] = listado_productores['MUNICIPIO'].apply(clean_text)
listado_productores['Estado-mun-KEY'] = listado_productores['ESTADO_Clean'].astype(str) + '-' + listado_productores[
    'MUNICIPIO_Clean'].astype(str)

diccionario_Sin_VC = diccionario[diccionario["NOM_ENT"] != "Veracruz de Ignacio de la Llave"]

# %%
listado_productores.shape
# Out:
# (1627152, 10)

# %%
diccionario_Sin_VC = diccionario_Sin_VC[['CVE_ENT', 'NOM_ENT', 'CVE_MUN', 'NOM_MUN', 'CVE_MUN_Unique',
       'KEY_inegi', 'best_match', 'match_score', 'ESTADO_Clean', 'MUNICIPIO_Clean', 'KEY_prod']]

diccionario_Sin_VC.shape
# Out:
# (2059, 11)

# %%
diccionario_Sin_VC.to_csv('../../data/productores_autorizados/diccionarios_E1/diccionario_prod_sin_VERACRUZ.csv', index=False)
diccionario_Sin_VC.columns
# Out:
# Index(['CVE_ENT', 'NOM_ENT', 'CVE_MUN', 'NOM_MUN', 'CVE_MUN_Unique',
#        'KEY_inegi', 'best_match', 'match_score', 'ESTADO_Clean',
#        'MUNICIPIO_Clean', 'KEY_prod'],
#       dtype='object')

# %%
# Lectura del diccionario manipulado
diccionario_manipulado = pd.read_csv('../../data/productores_autorizados/diccionarios_E1/diccionario_prod_sin_VERACRUZ.csv')

# %%
# Hacer el join
listado_productores_complete = pd.merge(listado_productores, diccionario_manipulado, left_on="Estado-mun-KEY",
                                        right_on="KEY_prod", how='left', suffixes=('_prod', '_inegi'))

# %%
listado_productores_complete[['CVE_ENT', 'CVE_MUN']] = listado_productores_complete['CVE_MUN_Unique'].str.split('-',
                                                                                                                expand=True)

# %%
listado_productores_complete.columns
# Out:
# Index(['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO',
#        'NOMBRE (S)', 'PAQUETE', 'ESTADO_Clean_prod', 'MUNICIPIO_Clean_prod',
#        'Estado-mun-KEY', 'CVE_ENT', 'NOM_ENT', 'CVE_MUN', 'NOM_MUN',
#        'CVE_MUN_Unique', 'KEY_inegi', 'best_match', 'match_score',
#        'ESTADO_Clean_inegi', 'MUNICIPIO_Clean_inegi', 'KEY_prod'],
#       dtype='object')

# %%
# Seleccionamos las columnas que nos interesan
listado_productores_complete = listado_productores_complete[
    ['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO',
     'NOMBRE (S)', 'PAQUETE', 'KEY_inegi', 'NOM_ENT', 'NOM_MUN', 'CVE_ENT', 'CVE_MUN']]

# %%
# Revisamos el dataset
print(listado_productores_complete.shape)
print(listado_productores_complete.columns)
print(listado_productores_complete.head())
# Out:
# (1627152, 12)
# Index(['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO',
#        'NOMBRE (S)', 'PAQUETE', 'KEY_inegi', 'NOM_ENT', 'NOM_MUN', 'CVE_ENT',
#        'CVE_MUN'],
#       dtype='object')
#      ESTADO                     MUNICIPIO                           ACUSE  \
# 0  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000018-S000-TL
# 1  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000016-S000-TL
# 2  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000005-S000-TL
# 3  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000006-S000-TL
# 4  TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO  23-PRONAFE-FERT-000007-S000-TL
#
#   APELLIDO PATERNO APELLIDO MATERNO          NOMBRE (S)  PAQUETE  \
# 0           AGUILA             LIMA          J. EUGENIO        2
# 1            CORTE         ESPINOZA  MA. PETRA APOLONIA        2
# 2            CORTE           PICHON              TERESA        2
# 3      CUAHTEPITZI             LUNA           FLORENCIO        2
# 4      CUAHTEPITZI          SANCHEZ   JOSE SIMON MARTIN        2
#
#                                KEY_inegi   NOM_ENT  \
# 0  tlaxcala-acuamanala de miguel hidalgo  Tlaxcala
# 1  tlaxcala-acuamanala de miguel hidalgo  Tlaxcala
# 2  tlaxcala-acuamanala de miguel hidalgo  Tlaxcala
# 3  tlaxcala-acuamanala de miguel hidalgo  Tlaxcala
# 4  tlaxcala-acuamanala de miguel hidalgo  Tlaxcala
#
#                         NOM_MUN CVE_ENT CVE_MUN
# 0  Acuamanala de Miguel Hidalgo      29     022
# 1  Acuamanala de Miguel Hidalgo      29     022
# 2  Acuamanala de Miguel Hidalgo      29     022
# 3  Acuamanala de Miguel Hidalgo      29     022
# 4  Acuamanala de Miguel Hidalgo      29     022

# %%
listado_productores_complete.to_csv('../../data/listados_completos/listado_productores_complete2023.csv', index=False)

# %% [markdown]
# # Adicional

# %%
unique_listado = listado_productores['Estado-mun-KEY'].unique()
unique_diccionario = diccionario_Sin_VC['KEY_prod'].unique()

# To get the common values
common_values = set(unique_listado).intersection(unique_diccionario)
print("Common values:", common_values)

# To get values in listado_productores not in diccionario_Sin_VC
in_listado_not_diccionario = set(unique_listado) - set(unique_diccionario)
print("Values in 'listado_productores' not in 'diccionario_Sin_VC':", in_listado_not_diccionario)
# Out:
# Common values: {'sonora-nacori chico', 'chiapas-frontera hidalgo', 'hidalgo-huehuetla', 'oaxaca-san vicente coatlan', 'michoacan de ocampo-los reyes', 'san luis potosi-el naranjo', 'chiapas-acapetahua', 'san luis potosi-san antonio', 'michoacan de ocampo-contepec', 'tlaxcala-munoz de domingo arenas', 'chihuahua-nonoava', 'jalisco-zapopan', 'michoacan de ocampo-jacona', 'yucatan-dzan', 'oaxaca-santa maria lachixio', 'oaxaca-santa maria chilchotla', 'puebla-san jeronimo tecuanipan', 'tabasco-centla', 'chiapas-acacoyagua', 'oaxaca-santa ines del monte', 'oaxaca-san jose lachiguiri', 'hidalgo-atitalaquia', 'puebla-acteopan', 'puebla-san andres cholula', 'tlaxcala-emiliano zapata', 'oaxaca-san melchor betaza', 'oaxaca-san jacinto tlacotepec', 'oaxaca-san pedro jocotipac', 'puebla-san miguel ixitlan', 'jalisco-ayutla', 'hidalgo-zimapan', 'zacatecas-noria de angeles', 'oaxaca-san pedro cajonos', 'baja california-ensenada', 'zacatecas-villanueva', 'oaxaca-la pe', 'oaxaca-san miguel tilquiapam', 'nuevo leon-mina', 'mexico-zacualpan', 'tlaxcala-tlaxcala', 'michoacan de ocampo-susupuato', 'oaxaca-putla villa de guerrero', 'yucatan-tixmehuac', 'puebla-chiconcuautla', 'oaxaca-chiquihuitlan de benito juarez', 'chihuahua-cusihuiriachi', 'puebla-huehuetla', 'coahuila de zaragoza-candela', 'oaxaca-san jose tenango', 'puebla-zoquitlan', 'mexico-texcoco', 'hidalgo-san agustin metzquititlan', 'guerrero-tlapa de comonfort', 'chiapas-aldama', 'chiapas-rincon chamula san pedro', 'oaxaca-tanetze de zaragoza', 'mexico-jiquipilco', 'oaxaca-santo domingo chihuitan', 'san luis potosi-matlapa', 'yucatan-xocchel', 'oaxaca-san andres zabache', 'mexico-san mateo atenco', 'jalisco-san cristobal de la barranca', 'michoacan de ocampo-aporo', 'mexico-otzoloapan', 'jalisco-tala', 'puebla-jolalpan', 'chiapas-arriaga', 'puebla-ixcamilpa de guerrero', 'puebla-cuautlancingo', 'yucatan-dzoncauich', 'michoacan de ocampo-cheran', 'puebla-nauzontla', 'oaxaca-magdalena tequisistlan', 'oaxaca-santa catarina ixtepeji', 'tlaxcala-huamantla', 'hidalgo-huasca de ocampo', 'jalisco-juchitlan', 'tamaulipas-matamoros', 'yucatan-tekom', 'hidalgo-santiago tulantepec de lugo guerrero', 'oaxaca-san miguel tlacamama', 'oaxaca-san miguel panixtlahuaca', 'oaxaca-san agustin chayuco', 'campeche-palizada', 'guerrero-coyuca de catalan', '
# %%
# To get values in diccionario_Sin_VC not in listado_productores
in_diccionario_not_listado = set(unique_diccionario) - set(unique_listado)
print("Values in 'diccionario_Sin_VC' not in 'listado_productores':", in_diccionario_not_listado)
# Create a DataFrame with unique values from 'listado_productores'
df_relations = pd.DataFrame(unique_listado, columns=['Estado-mun-KEY'])# Check if each value is present in 'diccionario_Sin_VC'
df_relations['In_diccionario_Sin_VC'] = df_relations['Estado-mun-KEY'].isin(unique_diccionario)
# Out:
# Values in 'diccionario_Sin_VC' not in 'listado_productores': set()

# %%
# Repeat the process for 'diccionario_Sin_VC'
df_relations_diccionario = pd.DataFrame(unique_diccionario, columns=['KEY_prod'])
df_relations_diccionario['In_listado_productores'] = df_relations_diccionario['KEY_prod'].isin(unique_listado)

# Merge the two DataFrames
df_relations = pd.merge(df_relations, df_relations_diccionario, left_on='Estado-mun-KEY', right_on='KEY_prod',
                        how='outer')

df_relations
# Out:
#                        Estado-mun-KEY  In_diccionario_Sin_VC  \
# 0       aguascalientes-aguascalientes                   True
# 1             aguascalientes-asientos                   True
# 2             aguascalientes-calvillo                   True
# 3                aguascalientes-cosio                   True
# 4             aguascalientes-el llano                   True
# ...                               ...                    ...
# 2284           zacatecas-villa garcia                   True
# 2285  zacatecas-villa gonzalez ortega                   True
# 2286          zacatecas-villa hidalgo                   True
# 2287             zacatecas-villanueva                   True
# 2288              zacatecas-zacatecas                   True
#
#                              KEY_prod In_listado_productores
# 0       aguascalientes-aguascalientes                   True
# 1             aguascalientes-asientos                   True
# 2             aguascalientes-calvillo                   True
# 3                aguascalientes-cosio                   True
# 4             aguascalientes-el llano                   True
# ...                               ...                    ...
# 2284           zacatecas-villa garcia                   True
# 2285  zacatecas-villa gonzalez ortega                   True
# 2286          zacatecas-villa hidalgo                   True
# 2287             zacatecas-villanueva                   True
# 2288              zacatecas-zacatecas                   True
#
# [2289 rows x 4 columns]

# %%
df_relations[(df_relations['In_diccionario_Sin_VC'] == False) | (df_relations['In_listado_productores'] == False)]
# Out:
#                                  Estado-mun-KEY  In_diccionario_Sin_VC  \
# 43                  chiapas-belisario dominguez                  False
# 60                            chiapas-cintalapa                  False
# 159                         chihuahua-batopilas                  False
# 249                            coahuila-abasolo                  False
# 250                              coahuila-acuna                  False
# ...                                         ...                    ...
# 2123                          veracruz-zaragoza                  False
# 2124                            veracruz-zentla                  False
# 2125                         veracruz-zongolica                  False
# 2126  veracruz-zontecomatlan de lopez y fuentes                  False
# 2127              veracruz-zozocolco de hidalgo                  False
#
#      KEY_prod In_listado_productores
# 43        NaN                    NaN
# 60        NaN                    NaN
# 159       NaN                    NaN
# 249       NaN                    NaN
# 250       NaN                    NaN
# ...       ...                    ...
# 2123      NaN                    NaN
# 2124      NaN                    NaN
# 2125      NaN                    NaN
# 2126      NaN                    NaN
# 2127      NaN                    NaN
#
# [230 rows x 4 columns]
