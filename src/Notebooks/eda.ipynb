# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. Carga De Datos

# %% [markdown]
# Primero, nos encargamos de cargar las bases de datos que sí se han descargado de la página web. (Cambiar función para leer todas las bases de datos posibles.) Haremos un inner join y de esta manera obtendremos un conjunto de datos con todas las bases de datos que se han descargado.

# %%
import pandas as pd
import seaborn as sns
from thefuzz import fuzz
from thefuzz import process
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
import re
import unidecode

def load_datasets(directory):
    # Get a list of all CSV files in the directory
    csv_files = glob.glob(os.path.join(directory, '*.csv'))

    # Read each CSV file and store the DataFrame in a list
    dataframes = [pd.read_csv(file, encoding='cp1252', index_col=0, skiprows=1) for file in csv_files]

    # Concatenate all DataFrames in the list
    merged_df = pd.concat(dataframes, join='inner', ignore_index=True)

    return merged_df

# %% [markdown]
# Cargamos el dataset de Inegi.

# %%
inegi_df = pd.read_csv('../../data/dataset_inegi.csv', encoding='cp1252')

# %%
inegi_df.columns
# Out:
# Index(['MAPA', 'Estatus', 'CVE_ENT', 'NOM_ENT', 'NOM_ABR', 'CVE_MUN',
#        'NOM_MUN', 'CVE_LOC', 'NOM_LOC', 'AMBITO', 'LATITUD', 'LONGITUD',
#        'LAT_DECIMAL', 'LON_DECIMAL', 'ALTITUD', 'CVE_CARTA', 'POB_TOTAL',
#        'POB_MASCULINA', 'POB_FEMENINA', 'TOTAL DE VIVIENDAS HABITADAS'],
#       dtype='object')

# %%
inegi_df = inegi_df.sort_values(by='NOM_ENT', ascending=True)

# %%
inegi_df.drop(columns=['MAPA'])
# Out:
#         Estatus  CVE_ENT         NOM_ENT NOM_ABR  CVE_MUN  \
# 0           NaN        1  Aguascalientes    Ags.        1
# 1909        NaN        1  Aguascalientes    Ags.        6
# 1910        NaN        1  Aguascalientes    Ags.        6
# 1911        NaN        1  Aguascalientes    Ags.        6
# 1912        NaN        1  Aguascalientes    Ags.        6
# ...         ...      ...             ...     ...      ...
# 295153      NaN       32       Zacatecas    Zac.       19
# 295152      NaN       32       Zacatecas    Zac.       19
# 295151      NaN       32       Zacatecas    Zac.       19
# 295161      NaN       32       Zacatecas    Zac.       19
# 299567      NaN       32       Zacatecas    Zac.       58
#
#                       NOM_MUN  CVE_LOC  \
# 0              Aguascalientes        1
# 1909      Pabellón de Arteaga      441
# 1910      Pabellón de Arteaga      442
# 1911      Pabellón de Arteaga      443
# 1912      Pabellón de Arteaga      444
# ...                       ...      ...
# 295153                  Jalpa      371
# 295152                  Jalpa      368
# 295151                  Jalpa      367
# 295161                  Jalpa      381
# 299567  Santa María de la Paz       43
#
#                                            NOM_LOC AMBITO         LATITUD  \
# 0                                   Aguascalientes      U  21°52´47.362N"
# 1909                                    Los Sauces      R  22°08´33.710N"
# 1910                                 Yiyo [Granja]      R  22°06´19.252N"
# 1911                                 Los Tulipanes      R  22°06´59.761N"
# 1912                        El Amarillo [Sociedad]      R  22°04´37.424N"
# ...                                            ...    ...             ...
# 295153  Fraccionamiento Solidaridad (El Fanfarrón)      R  21°37´08.255N"
# 295152                             Colonia del Sol      R  21°38´20.000N"
# 295151                               El Salitrillo      R  21°43´52.081N"
# 295161                  Fraccionamiento San Marcos      R  21°39´22.144N"
# 299567                                    Santa Fe      R  21°31´44.371N"
#
#                LONGITUD  LAT_DECIMAL  LON_DECIMAL  ALTITUD CVE_CARTA  \
# 0       102°17´45.768W"    21.879822  -102.296046     1878    F13D19
# 1909    102°18´05.905W"    22.142697  -102.301640     1900    F13B89
# 1910    102°15´14.132W"    22.105348  -102.253926     1911    F13B89
# 1911    102°15´40.931W"    22.116600  -102.261370     1899    F13B89
# 1912    102°19´05.023W"    22.077062  -102.318061     1922    F13B89
# ...                 ...          ...          ...      ...       ...
# 295153  102°59´49.976W"    21.618959  -102.997215     1411    F13D27
# 295152  103°00´04.000W"    21.638889  -103.001111     1444    F13D26
# 295151  102°51´54.317W"    21.731133  -102.865088     1519    F13D27
# 295161  102°59´46.469W"    21.656151  -102.996241     1445    F13D27
# 299567  103°23´06.343W"    21.528991  -103.385095     2021    F13D25
#
#        POB_TOTAL POB_MASCULINA POB_FEMENINA TOTAL DE VIVIENDAS HABITADAS
# 0         863893        419168       444725                       246259
# 1909           8             *            *                            2
# 1910          12             *            *                            2
# 1911           5             *            *                            1
# 1912           1             *            *                            1
# ...          ...           ...          ...                          ...
# 295153        33             *            *                            2
# 295152       196            98           98                           58
# 295151        60            26           34                           20
# 295161       304           153          151                           72
# 299567         0             0            0                            0
#
# [299568 rows x 19 columns]

# %%
inegi_df
# Out:
#              MAPA  Estatus  CVE_ENT         NOM_ENT NOM_ABR  CVE_MUN  \
# 0        10010001      NaN        1  Aguascalientes    Ags.        1
# 1909     10060441      NaN        1  Aguascalientes    Ags.        6
# 1910     10060442      NaN        1  Aguascalientes    Ags.        6
# 1911     10060443      NaN        1  Aguascalientes    Ags.        6
# 1912     10060444      NaN        1  Aguascalientes    Ags.        6
# ...           ...      ...      ...             ...     ...      ...
# 295153  320190371      NaN       32       Zacatecas    Zac.       19
# 295152  320190368      NaN       32       Zacatecas    Zac.       19
# 295151  320190367      NaN       32       Zacatecas    Zac.       19
# 295161  320190381      NaN       32       Zacatecas    Zac.       19
# 299567  320580043      NaN       32       Zacatecas    Zac.       58
#
#                       NOM_MUN  CVE_LOC  \
# 0              Aguascalientes        1
# 1909      Pabellón de Arteaga      441
# 1910      Pabellón de Arteaga      442
# 1911      Pabellón de Arteaga      443
# 1912      Pabellón de Arteaga      444
# ...                       ...      ...
# 295153                  Jalpa      371
# 295152                  Jalpa      368
# 295151                  Jalpa      367
# 295161                  Jalpa      381
# 299567  Santa María de la Paz       43
#
#                                            NOM_LOC AMBITO         LATITUD  \
# 0                                   Aguascalientes      U  21°52´47.362N"
# 1909                                    Los Sauces      R  22°08´33.710N"
# 1910                                 Yiyo [Granja]      R  22°06´19.252N"
# 1911                                 Los Tulipanes      R  22°06´59.761N"
# 1912                        El Amarillo [Sociedad]      R  22°04´37.424N"
# ...                                            ...    ...             ...
# 295153  Fraccionamiento Solidaridad (El Fanfarrón)      R  21°37´08.255N"
# 295152                             Colonia del Sol      R  21°38´20.000N"
# 295151                               El Salitrillo      R  21°43´52.081N"
# 295161                  Fraccionamiento San Marcos      R  21°39´22.144N"
# 299567                                    Santa Fe      R  21°31´44.371N"
#
#                LONGITUD  LAT_DECIMAL  LON_DECIMAL  ALTITUD CVE_CARTA  \
# 0       102°17´45.768W"    21.879822  -102.296046     1878    F13D19
# 1909    102°18´05.905W"    22.142697  -102.301640     1900    F13B89
# 1910    102°15´14.132W"    22.105348  -102.253926     1911    F13B89
# 1911    102°15´40.931W"    22.116600  -102.261370     1899    F13B89
# 1912    102°19´05.023W"    22.077062  -102.318061     1922    F13B89
# ...                 ...          ...          ...      ...       ...
# 295153  102°59´49.976W"    21.618959  -102.997215     1411    F13D27
# 295152  103°00´04.000W"    21.638889  -103.001111     1444    F13D26
# 295151  102°51´54.317W"    21.731133  -102.865088     1519    F13D27
# 295161  102°59´46.469W"    21.656151  -102.996241     1445    F13D27
# 299567  103°23´06.343W"    21.528991  -103.385095     2021    F13D25
#
#        POB_TOTAL POB_MASCULINA POB_FEMENINA TOTAL DE VIVIENDAS HABITADAS
# 0         863893        419168       444725                       246259
# 1909           8             *            *                            2
# 1910          12             *            *                            2
# 1911           5             *            *                            1
# 1912           1             *            *                            1
# ...          ...           ...          ...                          ...
# 295153        33             *            *                            2
# 295152       196            98           98                           58
# 295151        60            26           34                           20
# 295161       304           153          151                           72
# 299567         0             0            0                            0
#
# [299568 rows x 20 columns]

# %%
df = load_datasets("../../data/fertilizantes_autorizados")
df
# Out:
#            ESTADO                     MUNICIPIO  \
# 0        TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO
# 1        TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO
# 2        TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO
# 3        TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO
# 4        TLAXCALA  ACUAMANALA DE MIGUEL HIDALGO
# ...           ...                           ...
# 1525715    PUEBLA                     ZOQUITLAN
# 1525716    PUEBLA                     ZOQUITLAN
# 1525717    PUEBLA                     ZOQUITLAN
# 1525718    PUEBLA                     ZOQUITLAN
# 1525719    PUEBLA                     ZOQUITLAN
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 0        23-PRONAFE-FERT-000018-S000-TL           AGUILA             LIMA
# 1        23-PRONAFE-FERT-000016-S000-TL            CORTE         ESPINOZA
# 2        23-PRONAFE-FERT-000005-S000-TL            CORTE           PICHON
# 3        23-PRONAFE-FERT-000006-S000-TL      CUAHTEPITZI             LUNA
# 4        23-PRONAFE-FERT-000007-S000-TL      CUAHTEPITZI          SANCHEZ
# ...                                 ...              ...              ...
# 1525715  23-PRONAFE-FERT-103186-S000-PL         ZAQUEROZ         MONTALVO
# 1525716  23-PRONAFE-FERT-103187-S000-PL         ZAQUEROZ          SANCHEZ
# 1525717  23-PRONAFE-FERT-103188-S000-PL         ZAQUEROZ          SANCHEZ
# 1525718  23-PRONAFE-FERT-103189-S000-PL         ZAQUEROZ          SANCHEZ
# 1525719  23-PRONAFE-FERT-103190-S000-PL         ZAQUEROZ           TORRES
#
#                  NOMBRE (S)  PAQUETE
# 0                J. EUGENIO        2
# 1        MA. PETRA APOLONIA        2
# 2                    TERESA        2
# 3                 FLORENCIO        2
# 4         JOSE SIMON MARTIN        2
# ...                     ...      ...
# 1525715            ZEFERINO        1
# 1525716           CRECENCIO        2
# 1525717                JOSE        1
# 1525718              MARTIN        1
# 1525719       ANDRES ELIGIO        2
#
# [1525720 rows x 7 columns]

# %%
df = df.sort_values(by='ESTADO', ascending=True)

# %%
df
# Out:
#                 ESTADO MUNICIPIO                           ACUSE  \
# 34608   AGUASCALIENTES  TEPEZALA  23-PRONAFE-FERT-006426-S000-AS
# 30133   AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-001512-S000-AS
# 30134   AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-001872-S000-AS
# 30135   AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-001538-S000-AS
# 30136   AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-002131-S000-AS
# ...                ...       ...                             ...
# 437502         YUCATAN   HALACHO  23-PRONAFE-FERT-009316-S000-YN
# 437501         YUCATAN   HALACHO  23-PRONAFE-FERT-009315-S000-YN
# 437500         YUCATAN   HALACHO  23-PRONAFE-FERT-009313-S000-YN
# 437524         YUCATAN   HALACHO  23-PRONAFE-FERT-009338-S000-YN
# 442423         YUCATAN   OPICHEN  23-PRONAFE-FERT-015265-S000-YN
#
#        APELLIDO PATERNO APELLIDO MATERNO      NOMBRE (S)  PAQUETE
# 34608              VERA         MARTINEZ         ROBERTO        2
# 30133           SANCHEZ           BERNAL           LIDIA        1
# 30134           SANCHEZ           BERNAL        VICTORIO        2
# 30135           SANCHEZ           CAMPOS             EVA        2
# 30136           SANCHEZ         CASTILLO         ALFONSO        2
# ...                 ...              ...             ...      ...
# 437502             TZEK               KU            ELOY        1
# 437501             TZEK           CAUICH         ENRIQUE        1
# 437500             TZEK            CANUL        FAUSTINO        1
# 437524               UC            CANUL  RICARDO MIGUEL        1
# 442423              CHI             POOL   VICTOR ELADIO        1
#
# [1525720 rows x 7 columns]

# %% [markdown]
# ## 2. Análisis del problema

# %% [markdown]
# ### 2.1 Estructura de los datos

# %% [markdown]
# Comencemos por ver como ha quedado el principio y final de nuestro dataset, si la union no ha sido correcta podremos verlos aquí.

# %%
df.head()
# Out:
#                ESTADO MUNICIPIO                           ACUSE  \
# 34608  AGUASCALIENTES  TEPEZALA  23-PRONAFE-FERT-006426-S000-AS
# 30133  AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-001512-S000-AS
# 30134  AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-001872-S000-AS
# 30135  AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-001538-S000-AS
# 30136  AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-002131-S000-AS
#
#       APELLIDO PATERNO APELLIDO MATERNO NOMBRE (S)  PAQUETE
# 34608             VERA         MARTINEZ    ROBERTO        2
# 30133          SANCHEZ           BERNAL      LIDIA        1
# 30134          SANCHEZ           BERNAL   VICTORIO        2
# 30135          SANCHEZ           CAMPOS        EVA        2
# 30136          SANCHEZ         CASTILLO    ALFONSO        2

# %%
df.tail()
# Out:
#          ESTADO MUNICIPIO                           ACUSE APELLIDO PATERNO  \
# 437502  YUCATAN   HALACHO  23-PRONAFE-FERT-009316-S000-YN             TZEK
# 437501  YUCATAN   HALACHO  23-PRONAFE-FERT-009315-S000-YN             TZEK
# 437500  YUCATAN   HALACHO  23-PRONAFE-FERT-009313-S000-YN             TZEK
# 437524  YUCATAN   HALACHO  23-PRONAFE-FERT-009338-S000-YN               UC
# 442423  YUCATAN   OPICHEN  23-PRONAFE-FERT-015265-S000-YN              CHI
#
#        APELLIDO MATERNO      NOMBRE (S)  PAQUETE
# 437502               KU            ELOY        1
# 437501           CAUICH         ENRIQUE        1
# 437500            CANUL        FAUSTINO        1
# 437524            CANUL  RICARDO MIGUEL        1
# 442423             POOL   VICTOR ELADIO        1

# %% [markdown]
# ### 2.2 Información general
# Siempre es importante entender nuestras variables un poco mejor.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1525720 entries, 34608 to 442423
# Data columns (total 7 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   ESTADO            1525720 non-null  object
#  1   MUNICIPIO         1450208 non-null  object
#  2   ACUSE             1525720 non-null  object
#  3   APELLIDO PATERNO  1521426 non-null  object
#  4   APELLIDO MATERNO  1497507 non-null  object
#  5   NOMBRE (S)        1521427 non-null  object
#  6   PAQUETE           1525720 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 93.1+ MB

# %% [markdown]
# Habrá que cambiar el tipo de las variables para que salgan con la implementacion que nos han pedido.

# %% [markdown]
# ### 2.3 Estadísticas descriptivas

# %% [markdown]
# Changes in the types of variables need to be made.

# %%
df.describe()
# Out:
#             PAQUETE
# count  1.525720e+06
# mean   1.463099e+00
# std    4.986366e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    2.000000e+00
# max    2.000000e+00

# %% [markdown]
# # 3. Limpieza de datos

# %% [markdown]
# ### 3.1 Valores nulos o faltantes

# %%
df.isna().sum()
# Out:
# ESTADO                  0
# MUNICIPIO           75512
# ACUSE                   0
# APELLIDO PATERNO     4294
# APELLIDO MATERNO    28213
# NOMBRE (S)           4293
# PAQUETE                 0
# dtype: int64

# %%
df_municipio = df[df['MUNICIPIO'].isna()]

# %%
df_municipio
# Out:
#                                  ESTADO MUNICIPIO  \
# 766777  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 766791  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 766790  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 766789  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 766788  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# ...                                 ...       ...
# 782662  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 782661  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 782660  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 782659  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
# 782666  VERACRUZ DE IGNACIO DE LA LLAVE       NaN
#
#                                  ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 766777  23-PRONAFE-FERT-017104-S000-VZ             VERA        RODRIGUEZ
# 766791  23-PRONAFE-FERT-017119-S000-VZ         VICENCIO             CRUZ
# 766790  23-PRONAFE-FERT-017118-S000-VZ         VICENCIO         CARBALLO
# 766789  23-PRONAFE-FERT-017117-S000-VZ         VICENCIO         BAUTISTA
# 766788  23-PRONAFE-FERT-017116-S000-VZ         VICENCIO         BAUTISTA
# ...                                ...              ...              ...
# 782662  23-PRONAFE-FERT-034059-S000-VZ          GALMICH         MARTINEZ
# 782661  23-PRONAFE-FERT-034057-S000-VZ          GALMICH         MARTINEZ
# 782660  23-PRONAFE-FERT-034056-S000-VZ          GALMICH          JOACHIN
# 782659  23-PRONAFE-FERT-034055-S000-VZ          GALMICH          JIMENEZ
# 782666  23-PRONAFE-FERT-034064-S000-VZ          GALMICH            ROSAS
#
#        NOMBRE (S)  PAQUETE
# 766777     MIGUEL        2
# 766791     ADRIAN        2
# 766790      ANGEL        2
# 766789      TOMAS        2
# 766788    EUSEBIO        2
# ...           ...      ...
# 782662   VICTORIA        1
# 782661    ANTONIO        2
# 782660   OLIVERIO        2
# 782659     CIRILO        2
# 782666  MAGDALENO        2
#
# [75512 rows x 7 columns]

# %%
df[df['MUNICIPIO'].isna()].groupby('ESTADO').size()
# Out:
# ESTADO
# VERACRUZ DE IGNACIO DE LA LLAVE    75512
# dtype: int64

# %% [markdown]
# Aquí hay algo raro; como podemos ver la variable ESTADO para VERACRUZ DE IGNACIO DE LA LLAVE contiene todos los valores faltantes de la variable municipio.

# %%
df_municipio_nan = df[df['MUNICIPIO'].isna()]

# Step 2: Further filter to get rows where either 'NOMBRE(S)' or 'APELLIDO PATERNO' are NaN
df_filtered = df_municipio_nan[(df_municipio_nan['NOMBRE (S)'].isna()) | (df_municipio_nan['APELLIDO PATERNO'].isna())]

# %%
df_filtered
# Out:
# Empty DataFrame
# Columns: [ESTADO, MUNICIPIO, ACUSE, APELLIDO PATERNO, APELLIDO MATERNO, NOMBRE (S), PAQUETE]
# Index: []

# %% [markdown]
# No existe ninguna valor para el que NOMBRE (S) o APELLIDO PATERNO este vacío a la vez.

# %%
(df == 0).sum()
# Out:
# ESTADO              0
# MUNICIPIO           0
# ACUSE               0
# APELLIDO PATERNO    0
# APELLIDO MATERNO    0
# NOMBRE (S)          0
# PAQUETE             0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                 ESTADO MUNICIPIO                           ACUSE  \
# 30127   AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-001620-S000-AS
# 30084   AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-002572-S000-AS
# 29672   AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-000954-S000-AS
# 29876   AGUASCALIENTES  ASIENTOS  23-PRONAFE-FERT-002493-S000-AS
# 30536   AGUASCALIENTES  CALVILLO  23-PRONAFE-FERT-002802-S000-AS
# ...                ...       ...                             ...
# 437723         YUCATAN    HOCTUN  23-PRONAFE-FERT-009571-S000-YN
# 437549         YUCATAN   HALACHO  23-PRONAFE-FERT-008846-S000-YN
# 437528         YUCATAN   HALACHO  23-PRONAFE-FERT-009344-S000-YN
# 437555         YUCATAN   HALACHO  23-PRONAFE-FERT-009384-S000-YN
# 437554         YUCATAN   HALACHO  23-PRONAFE-FERT-009365-S000-YN
#
#        APELLIDO PATERNO APELLIDO MATERNO      NOMBRE (S)  PAQUETE
# 30127             SALAS              NaN         ANTONIO        2
# 30084         RODRIGUEZ              NaN     JUAN MANUEL        2
# 29672           MENDOZA              NaN  ANDREA ZITLALY        2
# 29876              PIÑA              NaN   JORGE ALBERTO        2
# 30536             REYES              NaN    M. GUADALUPE        1
# ...                 ...              ...             ...      ...
# 437723             COBA              NaN   JOSE ANACLETO        2
# 437549          VAZQUEZ              NaN       YNDALECIO        1
# 437528             UCAN              NaN        FILOMENO        1
# 437555              YAH              NaN     PEDRO PABLO        1
# 437554              YAH              NaN        EMILIANO        2
#
# [102786 rows x 7 columns]

# %% [markdown]
# Si no hay nombre del productor acreditado lo quitamos. También en el caso de que no haya apellido paterno. Un valor sin nombre y apellido no tiene uso práctico alguno.

# %%
#df = df.dropna(subset=['NOMBRE (S)'])
#df = df.dropna(subset=['APELLIDO PATERNO'])

# %%
df.isna().sum()
# Out:
# ESTADO                  0
# MUNICIPIO           75512
# ACUSE                   0
# APELLIDO PATERNO     4294
# APELLIDO MATERNO    28213
# NOMBRE (S)           4293
# PAQUETE                 0
# dtype: int64

# %% [markdown]
# ### 3.2 Valores duplicados

# %%
duplicate_rows_df = df[df.duplicated()]
duplicate_rows_df.shape
# Out:
# (0, 7)

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
duplicate_rows_df = df[df.duplicated()]
duplicate_rows_df.shape
# Out:
# (0, 7)

# %% [markdown]
# No hemos encontrado duplicados en este caso. En caso de que los hayan serán eliminados.

# %% [markdown]
# ### 3.3 Corrección del tipo de datos

# %%
df.dtypes
# Out:
# ESTADO              object
# MUNICIPIO           object
# ACUSE               object
# APELLIDO PATERNO    object
# APELLIDO MATERNO    object
# NOMBRE (S)          object
# PAQUETE              int64
# dtype: object

# %%
df = df.astype({
    'ESTADO' : 'string',
    'MUNICIPIO' : 'string',
    'ACUSE' : 'string',
    'APELLIDO PATERNO' : 'string',
    'APELLIDO MATERNO' : 'string',
    'NOMBRE (S)' : 'string',
})

# %%
df.dtypes
# Out:
# ESTADO              string
# MUNICIPIO           string
# ACUSE               string
# APELLIDO PATERNO    string
# APELLIDO MATERNO    string
# NOMBRE (S)          string
# PAQUETE              int64
# dtype: object

# %% [markdown]
# # 3.4 Formatear strings

# %% [markdown]
# Necesitamos que los strings de ESTADO y MUNCIPIO esten de forma concreta para hacer esto dividirimos el proceso en dos pasos.

# %% [markdown]
# ### 3.4.1 Limpieza general

# %%
def clean_text(text):
    if pd.isna(text):
        return text
    text = text.strip()  # Eliminate white spaces
    text = text.lower()  # Convert to lowercase
    text = unidecode.unidecode(text)  # Remove accents
    text = re.sub('\s+', ' ', text)  # Eliminate extra white spaces
    text = re.sub('^\s+|\s+?$', '', text)  # Eliminate spaces at the beginning and end
    return text

# %% [markdown]
# De esta manera tenemos el texto sin espacios blancos extra y sobre todo con todas las palabras con capitalización correcta.

# %% [markdown]
# ### 3.4.2 Ortografía

# %% [markdown]
# Necesitamos que los estados y municipios de nuestro dataset estén escritos igual que en el dataset de Inegi (en el cual están escritos sin faltas de ortografía), para luego poder hacer el map del cve_ent y cve_mun.

# %%
# Create the first DataFrame
df1 = pd.DataFrame({
    'ESTADO': pd.Series(df['ESTADO']),
    'MUNICIPIO': pd.Series(df['MUNICIPIO']),
})

# Create the second DataFrame
df2 = pd.DataFrame({
    'NOM_ENT': pd.Series(inegi_df['NOM_ENT']),
    'NOM_MUN': pd.Series(inegi_df['NOM_MUN']),
})

# %%
df1['ESTADO_CLEAN'] = df1['ESTADO'].apply(clean_text)
df1['MUNICIPIO_CLEAN'] = df1['MUNICIPIO'].apply(clean_text)

# %%
df2['NOM_ENT_CLEAN'] = df2['NOM_ENT'].apply(clean_text)
df2['NOM_MUN_CLEAN'] = df2['NOM_MUN'].apply(clean_text)

# %%
df1
# Out:
#                 ESTADO MUNICIPIO    ESTADO_CLEAN MUNICIPIO_CLEAN
# 34608   AGUASCALIENTES  TEPEZALA  aguascalientes        tepezala
# 30133   AGUASCALIENTES  ASIENTOS  aguascalientes        asientos
# 30134   AGUASCALIENTES  ASIENTOS  aguascalientes        asientos
# 30135   AGUASCALIENTES  ASIENTOS  aguascalientes        asientos
# 30136   AGUASCALIENTES  ASIENTOS  aguascalientes        asientos
# ...                ...       ...             ...             ...
# 437502         YUCATAN   HALACHO         yucatan         halacho
# 437501         YUCATAN   HALACHO         yucatan         halacho
# 437500         YUCATAN   HALACHO         yucatan         halacho
# 437524         YUCATAN   HALACHO         yucatan         halacho
# 442423         YUCATAN   OPICHEN         yucatan         opichen
#
# [1525720 rows x 4 columns]

# %%
df1.rename(columns={'ESTADO': 'estado', 'MUNICIPIO': 'municipio', 'ESTADO_CLEAN': 'estado_clean', 'MUNICIPIO_CLEAN': 'municipio_clean'}, inplace=True)

# %%
df2
# Out:
#                NOM_ENT                NOM_MUN   NOM_ENT_CLEAN  \
# 0       Aguascalientes         Aguascalientes  aguascalientes
# 1909    Aguascalientes    Pabellón de Arteaga  aguascalientes
# 1910    Aguascalientes    Pabellón de Arteaga  aguascalientes
# 1911    Aguascalientes    Pabellón de Arteaga  aguascalientes
# 1912    Aguascalientes    Pabellón de Arteaga  aguascalientes
# ...                ...                    ...             ...
# 295153       Zacatecas                  Jalpa       zacatecas
# 295152       Zacatecas                  Jalpa       zacatecas
# 295151       Zacatecas                  Jalpa       zacatecas
# 295161       Zacatecas                  Jalpa       zacatecas
# 299567       Zacatecas  Santa María de la Paz       zacatecas
#
#                 NOM_MUN_CLEAN
# 0              aguascalientes
# 1909      pabellon de arteaga
# 1910      pabellon de arteaga
# 1911      pabellon de arteaga
# 1912      pabellon de arteaga
# ...                       ...
# 295153                  jalpa
# 295152                  jalpa
# 295151                  jalpa
# 295161                  jalpa
# 299567  santa maria de la paz
#
# [299568 rows x 4 columns]

# %%
df2.rename(columns={'NOM_ENT': 'nom_ent', 'NOM_MUN': 'nom_mun', 'NOM_ENT_CLEAN': 'nom_ent_clean', 'NOM_MUN_CLEAN': 'nom_mun_clean'}, inplace=True)

# %%
# Create the first DataFrame
df3 = pd.DataFrame({
    'estado': pd.Series(df1['estado']),
    'estado_clean': pd.Series(df1['estado_clean']),

    'municipio': pd.Series(df1['municipio']),
    'municipio_clean': pd.Series(df1['municipio_clean']),

    'nom_ent': pd.Series(df2['nom_ent']),
    'nom_ent_clean': pd.Series(df2['nom_ent_clean']),

    'nom_mun': pd.Series(df2['nom_mun']),
    'nom_mun_clean': pd.Series(df2['nom_mun_clean']),
})

# %%
df3
# Out:
#            estado estado_clean                     municipio  \
# 0        TLAXCALA     tlaxcala  ACUAMANALA DE MIGUEL HIDALGO
# 1        TLAXCALA     tlaxcala  ACUAMANALA DE MIGUEL HIDALGO
# 2        TLAXCALA     tlaxcala  ACUAMANALA DE MIGUEL HIDALGO
# 3        TLAXCALA     tlaxcala  ACUAMANALA DE MIGUEL HIDALGO
# 4        TLAXCALA     tlaxcala  ACUAMANALA DE MIGUEL HIDALGO
# ...           ...          ...                           ...
# 1525715    PUEBLA       puebla                     ZOQUITLAN
# 1525716    PUEBLA       puebla                     ZOQUITLAN
# 1525717    PUEBLA       puebla                     ZOQUITLAN
# 1525718    PUEBLA       puebla                     ZOQUITLAN
# 1525719    PUEBLA       puebla                     ZOQUITLAN
#
#                       municipio_clean         nom_ent   nom_ent_clean  \
# 0        acuamanala de miguel hidalgo  Aguascalientes  aguascalientes
# 1        acuamanala de miguel hidalgo  Aguascalientes  aguascalientes
# 2        acuamanala de miguel hidalgo  Aguascalientes  aguascalientes
# 3        acuamanala de miguel hidalgo  Aguascalientes  aguascalientes
# 4        acuamanala de miguel hidalgo  Aguascalientes  aguascalientes
# ...                               ...             ...             ...
# 1525715                     zoquitlan             NaN             NaN
# 1525716                     zoquitlan             NaN             NaN
# 1525717                     zoquitlan             NaN             NaN
# 1525718                     zoquitlan             NaN             NaN
# 1525719                     zoquitlan             NaN             NaN
#
#                 nom_mun   nom_mun_clean
# 0        Aguascalientes  aguascalientes
# 1        Aguascalientes  aguascalientes
# 2        Aguascalientes  aguascalientes
# 3        Aguascalientes  aguascalientes
# 4        Aguascalientes  aguascalientes
# ...                 ...             ...
# 1525715             NaN             NaN
# 1525716             NaN             NaN
# 1525717             NaN             NaN
# 1525718             NaN             NaN
# 1525719             NaN             NaN
#
# [1525720 rows x 8 columns]

# %% [markdown]
# Creamos dataset con valores únicos de las 4 variables de arriba.

# %%
estado_clean_ratio = []
for estado in df3['estado_clean'].unique():
    if isinstance(estado, str):
        matches = process.extract(estado, df3['nom_ent_clean'].tolist(), limit=1, scorer=fuzz.ratio)
        if matches:
            nom_ent = df3[df3['nom_ent_clean'] == matches[0][0]]['nom_ent'].values[0]
        else:
            nom_ent = None
        estado_clean_ratio.append((estado, matches[0][0], matches[0][1], nom_ent))

municipio_clean_ratio = []
for _, row in df3[['estado_clean', 'nom_ent_clean', 'municipio_clean']].drop_duplicates().iterrows():
    estado, nom_ent, municipio = row['estado_clean'], row['nom_ent_clean'], row['municipio_clean'] 
    if isinstance(municipio, str):
        matches = process.extract(municipio, df3['nom_mun_clean'].tolist(), limit=1, scorer=fuzz.ratio)
        if matches:
            nom_mun = df3[df3['nom_mun_clean'] == matches[0][0]]['nom_mun'].values[0]
        else:
            nom_mun = None
        municipio_clean_ratio.append((estado, nom_ent, municipio, matches[0][0], matches[0][1], nom_mun))

# Convert the lists to DataFrames
# Convert the lists to DataFrames
df_ratio_estado = pd.DataFrame(estado_clean_ratio, columns=['estado_clean', 'nom_ent_clean_match', 'ratio_ent', 'final_estado'])
df_ratio_municipio = pd.DataFrame(municipio_clean_ratio, columns=['estado_clean', 'nom_ent_clean', 'municipio_clean', 'nom_mun_clean_match', 'ratio_mun', 'final_municipio'])

# %%
# Create a mapping from 'ESTADO_CLEAN' to 'MUNICIPIO_CLEAN' in df1
mapping_df1 = df1.groupby('municipio_clean')['estado_clean'].apply(set).to_dict()

# Create a mapping from 'NOM_ENT_CLEAN' to 'NOM_MUN_CLEAN' in df2
mapping_df2 = df2.groupby('nom_mun_clean')['nom_ent_clean'].apply(set).to_dict()

# %%
mapping_df1
# Out:
# {'abala': {'yucatan'},
#  'abejones': {'oaxaca'},
#  'acacoyagua': {'chiapas'},
#  'acajete': {'puebla'},
#  'acala': {'chiapas'},
#  'acambay': {'mexico'},
#  'acanceh': {'yucatan'},
#  'acapetahua': {'chiapas'},
#  'acapulco de juarez': {'guerrero'},
#  'acateno': {'puebla'},
#  'acatepec': {'guerrero'},
#  'acatic': {'jalisco'},
#  'acatlan': {'hidalgo', 'puebla'},
#  'acatlan de juarez': {'jalisco'},
#  'acatlan de perez figueroa': {'oaxaca'},
#  'acatzingo': {'puebla'},
#  'acaxochitlan': {'hidalgo'},
#  'acolman': {'mexico'},
#  'acteopan': {'puebla'},
#  'actopan': {'hidalgo'},
#  'acuamanala de miguel hidalgo': {'tlaxcala'},
#  'acuitzio': {'michoacan de ocampo'},
#  'aculco': {'mexico'},
#  'agua blanca de iturbide': {'hidalgo'},
#  'aguascalientes': {'aguascalientes'},
#  'aguililla': {'michoacan de ocampo'},
#  'ahuacatlan': {'puebla'},
#  'ahuacuotzingo': {'guerrero'},
#  'ahualulco de mercado': {'jalisco'},
#  'ahuatlan': {'puebla'},
#  'ahuazotepec': {'puebla'},
#  'ahuehuetitla': {'puebla'},
#  'ajacuba': {'hidalgo'},
#  'ajalpan': {'puebla'},
#  'ajuchitlan del progreso': {'guerrero'},
#  'akil': {'yucatan'},
#  'albino zertuche': {'puebla'},
#  'alcozauca de guerrero': {'guerrero'},
#  'aldama': {'chiapas'},
#  'alfajayucan': {'hidalgo'},
#  'aljojuca': {'puebla'},
#  'almoloya': {'hidalgo'},
#  'almoloya de alquisiras': {'mexico'},
#  'almoloya de juarez': {'mexico'},
#  'almoloya del rio': {'mexico'},
#  'alpoyeca': {'guerrero'},
#  'altamirano': {'chiapas'},
#  'altepexi': {'puebla'},
#  'alvaro obregon': {'ciudad de mexico', 'michoacan de ocampo'},
#  'amacueca': {'jalisco'},
#  'amacuzac': {'morelos'},
#  'amanalco': {'mexico'},
#  'amatan': {'chiapas'},
#  'amatenango de la frontera': {'chiapas'},
#  'amatenango del valle': {'chiapas'},
#  'amatepec': {'mexico'},
#  'amatitan': {'jalisco'},
#  'amaxac de guerrero': {'tlaxcala'},
#  'amealco de bonfil': {'queretaro de arteaga'},
#  'ameca': {'jalisco'},
#  'amecameca': {'mexico'},
#  'amixtlan': {'puebla'},
#  'amozoc': {'puebla'},
#  'angamacutiro': {'michoacan de ocampo'},
#  'angangueo': {'michoacan de ocampo'},
#  'angel albino corzo': {'chiapas'},
#  'animas trujano': {'oaxaca'},
#  'apan': {'hidalgo'},
#  'apatzingan': {'michoacan de ocampo'},
#  'apaxco': {'mexico'},
#  'apaxtla': {'guerrero'},
#  'apetatitlan de antonio carvajal': {'tlaxcala'},
#  'apizaco': {'tlaxcala'},
#  'aporo': {'michoacan de ocampo'},
#  'aquila': {'michoacan de ocampo'},
#  'aquixtla': {'puebla'},
#  'arandas': {'jalisco'},
#  'arcelia': {'guerrero'},
#  'ario': {'michoacan de ocampo'},
#  'armeria': {'colima'},
#  'arriaga': {'chiapas'},
#  'arroyo seco': {'queretaro de arteaga'},
#  'arteaga': {'michoacan de ocampo'},
#  'asientos': {'aguascalientes'},
#  'asuncion cacalotepec': {'oaxaca'},
#  'asuncion cuyotepeji': {'oaxaca'},
#  'asuncion ixtaltepec': {'oaxaca'},
#  'asuncion nochixtlan': {'oaxaca'},
#  'asuncion ocotlan': {'oaxaca'},
#  'asuncion tlacolulita': {'oaxaca'},
#  'atemajac de brizuela': {'jalisco'},
#  'atempan': {'puebla'},
#  'atenango del rio': {'guerrero'},
#  'atenco': {'mexico'},
#  'atengo': {'jalisco'},
#  'atenguillo': {'jalisco'},
#  'atexcal': {'puebla'},
#  'atitalaquia': {'hidalgo'},
#  'atizapan': {'mexico'},
#  'atizapan de zaragoza': {'mexico'},
#  'atlacomulco': {'mexico'},
#  'atlamajalcingo del monte': {'guerrero'},
#  'atlangatepec': {'tlaxcala'},
#  'atlapexco': {'hidalgo'},
#  'atlatlahucan': {'morelos'},
#  'atlautla': {'mexico'},
#  'atlequizayan': {'puebla'},
#  'atlixco': {'puebla'},
#  'atlixtac': {'guerrero'},
#  'atltzayanca': {'tlaxcala'},
#  'atotonilco de tula': {'hidalgo'},
#  'atotonilco el alto': {'jalisco'},
#  'atotonilco el grande': {'hidalgo'},
#  'atoyac': {'jalisco'},
#  'atoyac de alvarez': {'guerrero'},
#  'atoyatempan': {'puebla'},
#  'atzala': {'puebla'},
#  'atzitzihuacan': {'puebla'},
#  'atzitzintla': {'puebla'},
#  'autlan de navarro': {'jalisco'},
#  'axapusco': {'mexico'},
#  'axochiapan': {'morelos'},
#  'axutla': {'puebla'},
#  'ayala': {'morelos'},
#  'ayapango': {'mexico'},
#  'ayoquezco de aldama': {'oaxaca'},
#  'ayotlan': {'jalisco'},
#  'ayotoxco de guerrero': {'puebla'},
#  'ayotzintepec': {'oaxaca'},
#  'ayutla': {'jalisco'},
#  'ayutla de los libres': {'guerrero'},
#  'azoyu': {'guerrero'},
#  'baca': {'yucatan'},
#  'bacalar': {'quintana roo'},
#  'bejucal de ocampo': {'chiapas'},
#  'belisario dominguez': {'chiapas'},
#  'bella vista': {'chiapas'},
#  'benemerito de las americas': {'chiapas'},
#  'benito juarez': {'guerrero', 'quintana roo', 'tlaxcala'},
#  'berriozabal': {'chiapas'},
#  'bochil': {'chiapas'},
#  'bokoba': {'yucatan'},
#  'bolanos': {'jalisco'},
#  'brisenas': {'michoacan de ocampo'},
#  'buctzotz': {'yucatan'},
#  'buenavista': {'michoacan de ocampo'},
#  'buenavista de cuellar': {'guerrero'},
#  'cabo corrientes': {'jalisco'},
#  'cacahoatan': {'chiapas'},
#  'cacalchen': {'yucatan'},
#  'cadereyta de montes': {'queretaro de arteaga'},
#  'calakmul': {'campeche'},
#  'calihuala': {'oaxaca'},
#  'calimaya': {'mexico'},
#  'calkini': {'campeche'},
#  'calnali': {'hidalgo'},
#  'calotmul': {'yucatan'},
#  'calpan': {'puebla'},
#  'calpulalpan': {'tlaxcala'},
#  'caltepec': {'puebla'},
#  'calvillo': {'aguascalientes'},
#  'camocuautla': {'puebla'},
#  'campeche': {'campeche'},
#  'canada morelos': {'puebla'},
#  'canadas de obregon': {'jalisco'},
#  'canatlan': {'durango'},
#  'candelaria': {'campeche'},
#  'candelaria loxicha': {'oaxaca'},
#  'canelas': {'durango'},
#  'cansahcab': {'yucatan'},
#  'cantamayec': {'yucatan'},
#  'capulalpam de mendez': {'oaxaca'},
#  'capulhuac': {'mexico'},
#  'caracuaro': {'michoacan de ocampo'},
#  'cardonal': {'hidalgo'},
#  'carmen': {'campeche'},
#  'casimiro castillo': {'jalisco'},
#  'catazaja': {'chiapas'},
#  'caxhuacan': {'puebla'},
#  'celestun': {'yucatan'},
#  'cenotillo': {'yucatan'},
#  'chacsinkin': {'yucatan'},
#  'chahuites': {'oaxaca'},
#  'chalcatongo de hidalgo': {'oaxaca'},
#  'chalchicomula de sesma': {'puebla'},
#  'chalchihuitan': {'chiapas'},
#  'chalco': {'mexico'},
#  'champoton': {'campeche'},
#  'chamula': {'chiapas'},
#  'chanal': {'chiapas'},
#  'chankom': {'yucatan'},
#  'chapa de mota': {'mexico'},
#  'chapab': {'yucatan'},
#  'chapala': {'jalisco'},
#  'chapantongo': {'hidalgo'},
#  'chapulco': {'puebla'},
#  'chapulhuacan': {'hidalgo'},
#  'chapultenango': {'chiapas'},
#  'chapultepec': {'mexico'},
#  'charapan': {'michoacan de ocampo'},
#  'charo': {'michoacan de ocampo'},
#  'chavinda': {'michoacan de ocampo'},
#  'chemax': {'yucatan'},
#  'chenalho': {'chiapas'},
#  'cheran': {'michoacan de ocampo'},
#  'chiapa de corzo': {'chiapas'},
#  'chiapilla': {'chiapas'},
#  'chiautempan': {'tlaxcala'},
#  'chiautla': {'mexico', 'puebla'},
#  'chiautzingo': {'puebla'},
#  'chichimila': {'yucatan'},
#  'chichiquila': {'puebla'},
#  'chicoasen': {'chiapas'},
#  'chicoloapan': {'mexico'},
#  'chicomuselo': {'chiapas'},
#  'chiconcuac': {'mexico'},
#  'chiconcuautla': {'puebla'},
#  'chietla': {'puebla'},
#  'chigmecatitlan': {'puebla'},
#  'chignahuapan': {'puebla'},
#  'chignautla': {'puebla'},
#  'chikindzonot': {'yucatan'},
#  'chila': {'puebla'},
#  'chila de la sal': {'puebla'},
#  'chilapa de alvarez': {'guerrero'},
#  'chilchota': {'michoacan de ocampo'},
#  'chilchotla': {'puebla'},
#  'chilcuautla': {'hidalgo'},
#  'chilon': {'chiapas'},
#  'chilpancingo de los bravo': {'guerrero'},
#  'chimalhuacan': {'mexico'},
#  'chimaltitan': {'jalisco'},
#  'chinantla': {'puebla'},
#  'chinicuila': {'michoacan de ocampo'},
#  'chiquihuitlan de benito juarez': {'oaxaca'},
#  'chiquilistlan': {'jalisco'},
#  'chochola': {'yucatan'},
#  'chucandiro': {'michoacan de ocampo'},
#  'chumayel': {'yucatan'},
#  'churintzio': {'michoacan de ocampo'},
#  'churumuco': {'michoacan de ocampo'},
#  'cienega de zimatlan': {'oaxaca'},
#  'cintalapa': {'chiapas'},
#  'ciudad ixtepec': {'oaxaca'},
#  'coacalco de berriozabal': {'mexico'},
#  'coahuayana': {'michoacan de ocampo'},
#  'coahuayutla de jose maria izazaga': {'guerrero'},
#  'coalcoman de vazquez pallares': {'michoacan de ocampo'},
#  'coapilla': {'chiapas'},
#  'coatecas altas': {'oaxaca'},
#  'coatepec': {'puebla'},
#  'coatepec harinas': {'mexico'},
#  'coatetelco': {'morelos'},
#  'coatlan del rio': {'morelos'},
#  'coatzingo': {'puebla'},
#  'cochoapa el grande': {'guerrero'},
#  'cocotitlan': {'mexico'},
#  'cocula': {'guerrero', 'jalisco'},
#  'coeneo': {'michoacan de ocampo'},
#  'cohetzala': {'puebla'},
#  'cohuecan': {'puebla'},
#  'coicoyan de las flores': {'oaxaca'},
#  'cojumatlan de regules': {'michoacan de ocampo'},
#  'colima': {'colima'},
#  'colon': {'queretaro de arteaga'},
#  'colotlan': {'jalisco'},
#  'comala': {'colima'},
#  'comitan de dominguez': {'chiapas'},
#  'concepcion buenavista': {'oaxaca'},
#  'concepcion de buenos aires': {'jalisco'},
#  'concepcion papalo': {'oaxaca'},
#  'coneto de comonfort': {'durango'},
#  'conkal': {'yucatan'},
#  'constancia del rosario': {'oaxaca'},
#  'contepec': {'michoacan de ocampo'},
#  'contla de juan cuamatzi': {'tlaxcala'},
#  'copainala': {'chiapas'},
#  'copala': {'guerrero'},
#  'copalillo': {'guerrero'},
#  'copanatoyac': {'guerrero'},
#  'copandaro': {'michoacan de ocampo'},
#  'coquimatlan': {'colima'},
#  'coronango': {'puebla'},
#  'corregidora': {'queretaro de arteaga'},
#  'cosio': {'aguascalientes'},
#  'cosolapa': {'oaxaca'},
#  'cosoltepec': {'oaxaca'},
#  'cotija': {'michoacan de ocampo'},
#  'coxcatlan': {'puebla'},
#  'coyoacan': {'ciudad de mexico'},
#  'coyomeapan': {'puebla'},
#  'coyotepec': {'mexico', 'puebla'},
#  'coyuca de benitez': {'guerrero'},
#  'coyuca de catalan': {'guerrero'},
#  'cuajimalpa de morelos': {'ciudad de mexico'},
#  'cuajinicuilapa': {'guerrero'},
#  'cualac': {'guerrero'},
#  'cuapiaxtla': {'tlaxcala'},
#  'cuapiaxtla de madero': {'puebla'},
#  'cuauhtemoc': {'colima'},
#  'cuautempan': {'puebla'},
#  'cuautepec': {'guerrero'},
#  'cuautepec de hinojosa': {'hidalgo'},
#  'cuautinchan': {'puebla'},
#  'cuautitlan': {'mexico'},
#  'cuautitlan de garcia barragan': {'jalisco'},
#  'cuautitlan izcalli': {'mexico'},
#  'cuautla': {'jalisco', 'morelos'},
#  'cuautlancingo': {'puebla'},
#  'cuaxomulco': {'tlaxcala'},
#  'cuayuca de andrade': {'puebla'},
#  'cuencame': {'durango'},
#  'cuernavaca': {'morelos'},
#  'cuetzala del progreso': {'guerrero'},
#  'cuetzalan del progreso': {'puebla'},
#  'cuilapam de guerrero': {'oaxaca'},
#  'cuitzeo': {'michoacan de ocampo'},
#  'cuncunul': {'yucatan'},
#  'cuquio': {'jalisco'},
#  'cutzamala de pinzon': {'guerrero'},
#  'cuyamecalco villa de zaragoza': {'oaxaca'},
#  'cuyoaco': {'puebla'},
#  'cuzama': {'yucatan'},
#  'degollado': {'jalisco'},
#  'domingo arenas': {'puebla'},
#  'donato guerra': {'mexico'},
#  'durango': {'durango'},
#  'dzan': {'yucatan'},
#  'dzemul': {'yucatan'},
#  'dzidzantun': {'yucatan'},
#  'dzilam de bravo': {'yucatan'},
#  'dzilam gonzalez': {'yucatan'},
#  'dzitas': {'yucatan'},
#  'dzoncauich': {'yucatan'},
#  'ecatepec de morelos': {'mexico'},
#  'ecatzingo': {'mexico'},
#  'ecuandureo': {'michoacan de ocampo'},
#  'eduardo neri': {'guerrero'},
#  'ejutla': {'jalisco'},
#  'el arenal': {'hidalgo', 'jalisco'},
#  'el barrio de la soledad': {'oaxaca'},
#  'el bosque': {'chiapas'},
#  'el carmen tequexquitla': {'tlaxcala'},
#  'el espinal': {'oaxaca'},
#  'el grullo': {'jalisco'},
#  'el limon': {'jalisco'},
#  'el llano': {'aguascalientes'},
#  'el marques': {'queretaro de arteaga'},
#  'el oro': {'durango', 'mexico'},
#  'el parral': {'chiapas'},
#  'el porvenir': {'chiapas'},
#  'el salto': {'jalisco'},
#  'eloxochitlan': {'hidalgo', 'puebla'},
#  'eloxochitlan de flores magon': {'oaxaca'},
#  'emiliano zapata': {'chiapas', 'hidalgo', 'morelos', 'tlaxcala'},
#  'encarnacion de diaz': {'jalisco'},
#  'epatlan': {'puebla'},
#  'epazoyucan': {'hidalgo'},
#  'epitacio huerta': {'michoacan de ocampo'},
#  'erongaricuaro': {'michoacan de ocampo'},
#  'escarcega': {'campeche'},
#  'escuintla': {'chiapas'},
#  'espanita': {'tlaxcala'},
#  'esperanza': {'puebla'},
#  'espita': {'yucatan'},
#  'etzatlan': {'jalisco'},
#  'ezequiel montes': {'queretaro de arteaga'},
#  'felipe carrillo puerto': {'quintana roo'},
#  'florencio villarreal': {'guerrero'},
#  'francisco i. madero': {'hidalgo'},
#  'francisco leon': {'chiapas'},
#  'francisco z. mena': {'puebla'},
#  'fresnillo de trujano': {'oaxaca'},
#  'frontera comalapa': {'chiapas'},
#  'frontera hidalgo': {'chiapas'},
#  'gabriel zamora': {'michoacan de ocampo'},
#  'general canuto a. neri': {'guerrero'},
#  'general felipe angeles': {'puebla'},
#  'general heliodoro castillo': {'guerrero'},
#  'general simon bolivar': {'durango'},
#  'gomez farias': {'jalisco'},
#  'guachinango': {'jalisco'},
#  'guadalajara': {'jalisco'},
#  'guadalupe': {'puebla'},
#  'guadalupe de ramirez': {'oaxaca'},
#  'guadalupe etla': {'oaxaca'},
#  'guadalupe victoria': {'durango', 'puebla'},
#  'guanacevi': {'durango'},
#  'guelatao de juarez': {'oaxaca'},
#  'guevea de humboldt': {'oaxaca'},
#  'halacho': {'yucatan'},
#  'hecelchakan': {'campeche'},
#  'hermenegildo galeana': {'puebla'},
#  'heroica ciudad de ejutla de crespo': {'oaxaca'},
#  'heroica ciudad de huajuapan de leon': {'oaxaca'},
#  'heroica ciudad de tlaxiaco': {'oaxaca'},
#  'hidalgo': {'durango', 'michoacan de ocampo'},
#  'hocaba': {'yucatan'},
#  'hoctun': {'yucatan'},
#  'homun': {'yucatan'},
#  'honduras de la sierra': {'chiapas'},
#  'honey': {'puebla'},
#  'hopelchen': {'campeche'},
#  'hostotipaquillo': {'jalisco'},
#  'huamantla': {'tlaxcala'},
#  'huamuxtitlan': {'guerrero'},
#  'huandacareo': {'michoacan de ocampo'},
#  'huaniqueo': {'michoacan de ocampo'},
#  'huaquechula': {'puebla'},
#  'huasca de ocampo': {'hidalgo'},
#  'huatlatlauca': {'puebla'},
#  'huauchinango': {'puebla'},
#  'huautepec': {'oaxaca'},
#  'huautla': {'hidalgo'},
#  'huautla de jimenez': {'oaxaca'},
#  'huazalingo': {'hidalgo'},
#  'huehuetan': {'chiapas'},
#  'huehuetla': {'hidalgo', 'puebla'},
#  'huehuetlan el chico': {'puebla'},
#  'huehuetlan el grande': {'puebla'},
#  'huehuetoca': {'mexico'},
#  'huejotzingo': {'puebla'},
#  'huejucar': {'jalisco'},
#  'huejuquilla el alto': {'jalisco'},
#  'huejutla de reyes': {'hidalgo'},
#  'huetamo': {'michoacan de ocampo'},
#  'hueyapan': {'morelos', 'puebla'},
#  'hueyotlipan': {'tlaxcala'},
#  'hueypoxtla': {'mexico'},
#  'hueytamalco': {'puebla'},
#  'hueytlalpan': {'puebla'},
#  'huhi': {'yucatan'},
#  'huichapan': {'hidalgo'},
#  'huimilpan': {'queretaro de arteaga'},
#  'huiramba': {'michoacan de ocampo'},
#  'huitiupan': {'chiapas'},
#  'huitzilac': {'morelos'},
#  'huitzilan de serdan': {'puebla'},
#  'huitziltepec': {'puebla'},
#  'huitzuco de los figueroa': {'guerrero'},
#  'huixquilucan': {'mexico'},
#  'huixtan': {'chiapas'},
#  'huixtla': {'chiapas'},
#  'hunucma': {'yucatan'},
#  'iguala de la independencia': {'guerrero'},
#  'igualapa': {'guerrero'},
#  'iliatenco': {'guerrero'},
#  'indaparapeo': {'michoacan de ocampo'},
#  'inde': {'durango'},
#  'irimbo': {'michoacan de ocampo'},
#  'isidro fabela': {'mexico'},
#  'isla mujeres': {'quintana roo'},
#  'ixcamilpa de guerrero': {'puebla'},
#  'ixcaquixtla': {'puebla'},
#  'ixcateopan de cuauhtemoc': {'guerrero'},
#  'ixhuatan': {'chiapas'},
#  'ixil': {'yucatan'},
#  'ixmiquilpan': {'hidalgo'},
#  'ixpantepec nieves': {'oaxaca'},
#  'ixtacamaxtitlan': {'puebla'},
#  'ixtacomitan': {'chiapas'},
#  'ixtacuixtla de mariano matamoros': {'tlaxcala'},
#  'ixtapa': {'chiapas'},
#  'ixtapaluca': {'mexico'},
#  'ixtapan de la sal': {'mexico'},
#  'ixtapan del oro': {'mexico'},
#  'ixtapangajoya': {'chiapas'},
#  'ixtenco': {'tlaxcala'},
#  'ixtepec': {'puebla'},
#  'ixtlahuaca': {'mexico'},
#  'ixtlahuacan': {'colima'},
#  'ixtlahuacan de los membrillos': {'jalisco'},
#  'ixtlahuacan del rio': {'jalisco'},
#  'ixtlan': {'michoacan de ocampo'},
#  'ixtlan de juarez': {'oaxaca'},
#  'izamal': {'yucatan'},
#  'iztapalapa': {'ciudad de mexico'},
#  'izucar de matamoros': {'puebla'},
#  'jacala de ledezma': {'hidalgo'},
#  'jacona': {'michoacan de ocampo'},
#  'jalostotitlan': {'jalisco'},
#  'jalpan': {'puebla'},
#  'jalpan de serra': {'queretaro de arteaga'},
#  'jaltenco': {'mexico'},
#  'jaltocan': {'hidalgo'},
#  'jamay': {'jalisco'},
#  'jantetelco': {'morelos'},
#  'jesus maria': {'aguascalientes', 'jalisco'},
#  'jilotepec': {'mexico'},
#  'jilotlan de los dolores': {'jalisco'},
#  'jilotzingo': {'mexico'},
#  'jimenez': {'michoacan de ocampo'},
#  'jiquilpan': {'michoacan de ocampo'},
#  'jiquipilas': {'chiapas'},
#  'jiquipilco': {'mexico'},
#  'jitotol': {'chiapas'},
#  'jiutepec': {'morelos'},
#  'jocotepec': {'jalisco'},
#  'jocotitlan': {'mexico'},
#  'jojutla': {'morelos'},
#  'jolalpan': {'puebla'},
#  'jonacatepec': {'morelos'},
#  'jonotla': {'puebla'},
#  'jopala': {'puebla'},
#  'joquicingo': {'mexico'},
#  'jose azueta': {'guerrero'},
#  'jose joaquin de herrera': {'guerrero'},
#  'jose maria morelos': {'quintana roo'},
#  'jose sixto verduzco': {'michoacan de ocampo'},
#  'juan c. bonilla': {'puebla'},
#  'juan n. mendez': {'puebla'},
#  'juan r. escudero': {'guerrero'},
#  'juanacatlan': {'jalisco'},
#  'juarez': {'chiapas', 'michoacan de ocampo'},
#  'juarez hidalgo': {'hidalgo'},
#  'juchitan': {'guerrero'},
#  'juchitan de zaragoza': {'oaxaca'},
#  'juchitepec': {'mexico'},
#  'juchitlan': {'jalisco'},
#  'jungapeo': {'michoacan de ocampo'},
#  'kanasin': {'yucatan'},
#  'kantunil': {'yucatan'},
#  'kaua': {'yucatan'},
#  'kinchil': {'yucatan'},
#  'kopoma': {'yucatan'},
#  'la barca': {'jalisco'},
#  'la compania': {'oaxaca'},
#  'la concordia': {'chiapas'},
#  'la grandeza': {'chiapas'},
#  'la huacana': {'michoacan de ocampo'},
#  'la huerta': {'jalisco'},
#  'la independencia': {'chiapas'},
#  'la libertad': {'chiapas'},
#  'la magdalena contreras': {'ciudad de mexico'},
#  'la magdalena tlaltelulco': {'tlaxcala'},
#  'la magdalena tlatlauquitepec': {'puebla'},
#  'la manzanilla de la paz': {'jalisco'},
#  'la mision': {'hidalgo'},
#  'la paz': {'mexico'},
#  'la pe': {'oaxaca'},
#  'la piedad': {'michoacan de ocampo'},
#  'la reforma': {'oaxaca'},
#  'la trinidad vista hermosa': {'oaxaca'},
#  'la trinitaria': {'chiapas'},
#  'la union de isidoro montes de oca': {'guerrero'},
#  'lafragua': {'puebla'},
#  'lagos de moreno': {'jalisco'},
#  'lagunillas': {'michoacan de ocampo'},
#  'landa de matamoros': {'queretaro de arteaga'},
#  'larrainzar': {'chiapas'},
#  'las margaritas': {'chiapas'},
#  'las rosas': {'chiapas'},
#  'lazaro cardenas': {'michoacan de ocampo', 'quintana roo', 'tlaxcala'},
#  'leonardo bravo': {'guerrero'},
#  'lerma': {'mexico'},
#  'libres': {'puebla'},
#  'lolotla': {'hidalgo'},
#  'loma bonita': {'oaxaca'},
#  'los reyes': {'michoacan de ocampo'},
#  'los reyes de juarez': {'puebla'},
#  'luvianos': {'mexico'},
#  'madero': {'michoacan de ocampo'},
#  'magdalena': {'jalisco'},
#  'magdalena apasco': {'oaxaca'},
#  'magdalena jaltepec': {'oaxaca'},
#  'magdalena mixtepec': {'oaxaca'},
#  'magdalena ocotlan': {'oaxaca'},
#  'magdalena penasco': {'oaxaca'},
#  'magdalena teitipac': {'oaxaca'},
#  'magdalena tequisistlan': {'oaxaca'},
#  'magdalena tlacotepec': {'oaxaca'},
#  'magdalena yodocono de porfirio diaz': {'oaxaca'},
#  'magdalena zahuatlan': {'oaxaca'},
#  'malinalco': {'mexico'},
#  'malinaltepec': {'guerrero'},
#  'mama': {'yucatan'},
#  'mani': {'yucatan'},
#  'manzanillo': {'colima'},
#  'mapastepec': {'chiapas'},
#  'mapimi': {'durango'},
#  'maravatio': {'michoacan de ocampo'},
#  'maravilla tenejapa': {'chiapas'},
#  'marcos castellanos': {'michoacan de ocampo'},
#  'mariscala de juarez': {'oaxaca'},
#  'marquelia': {'guerrero'},
#  'marques de comillas': {'chiapas'},
#  'martir de cuilapan': {'guerrero'},
#  'martires de tacubaya': {'oaxaca'},
#  'mascota': {'jalisco'},
#  'matias romero avendano': {'oaxaca'},
#  'maxcanu': {'yucatan'},
#  'mayapan': {'yucatan'},
#  'mazamitla': {'jalisco'},
#  'mazapa de madero': {'chiapas'},
#  'mazapiltepec de juarez': {'puebla'},
#  'mazatan': {'chiapas'},
#  'mazatecochco de jose maria morelos': {'tlaxcala'},
#  'mazatepec': {'morelos'},
#  'mazatlan villa de flores': {'oaxaca'},
#  'melchor ocampo': {'mexico'},
#  'merida': {'yucatan'},
#  'mesones hidalgo': {'oaxaca'},
#  'metapa': {'chiapas'},
#  'metepec': {'hidalgo', 'mexico'},
#  'metlatonoc': {'guerrero'},
#  'metztitlan': {'hidalgo'},
#  'mexicaltzingo': {'mexico'},
#  'mexticacan': {'jalisco'},
#  'mezcalapa': {'chiapas'},
#  'mezquital': {'durango'},
#  'mezquitic': {'jalisco'},
#  'miacatlan': {'morelos'},
#  'miahuatlan de porfirio diaz': {'oaxaca'},
#  'milpa alta': {'ciudad de mexico'},
#  'minatitlan': {'colima'},
#  'mineral de la reforma': {'hidalgo'},
#  'mineral del chico': {'hidalgo'},
#  'mineral del monte': {'hidalgo'},
#  'mitontic': {'chiapas'},
#  'mixistlan de la reforma': {'oaxaca'},
#  'mixquiahuala de juarez': {'hidalgo'},
#  'mixtla': {'puebla'},
#  'mixtlan': {'jalisco'},
#  'mochitlan': {'guerrero'},
#  'mococha': {'yucatan'},
#  'molango de escamilla': {'hidalgo'},
#  'molcaxac': {'puebla'},
#  'monjas': {'oaxaca'},
#  'montecristo de guerrero': {'chiapas'},
#  'morelia': {'michoacan de ocampo'},
#  'morelos': {'mexico', 'michoacan de ocampo'},
#  'motozintla': {'chiapas'},
#  'motul': {'yucatan'},
#  'mugica': {'michoacan de ocampo'},
#  'muna': {'yucatan'},
#  'munoz de domingo arenas': {'tlaxcala'},
#  'muxupip': {'yucatan'},
#  'nahuatzen': {'michoacan de ocampo'},
#  'nanacamilpa de mariano arista': {'tlaxcala'},
#  'nativitas': {'tlaxcala'},
#  'naucalpan de juarez': {'mexico'},
#  'naupan': {'puebla'},
#  'nauzontla': {'puebla'},
#  'nazareno etla': {'oaxaca'},
#  'nazas': {'durango'},
#  'nealtican': {'puebla'},
#  'nejapa de madero': {'oaxaca'},
#  'nextlalpan': {'mexico'},
#  'nezahualcoyotl': {'mexico'},
#  'nicolas bravo': {'puebla'},
#  'nicolas flores': {'hidalgo'},
#  'nicolas romero': {'mexico'},
#  'nicolas ruiz': {'chiapas'},
#  'nocupetaro': {'michoacan de ocampo'},
#  'nombre de dios': {'durango'},
#  'nopala de villagran': {'hidalgo'},
#  'nopaltepec': {'mexico'},
#  'nopalucan': {'puebla'},
#  'nuevo ideal': {'durango'},
#  'nuevo parangaricutiro': {'michoacan de ocampo'},
#  'nuevo urecho': {'michoacan de ocampo'},
#  'nuevo zoquiapam': {'oaxaca'},
#  'numaran': {'michoacan de ocampo'},
#  'oaxaca de juarez': {'oaxaca'},
#  'ocampo': {'durango', 'michoacan de ocampo'},
#  'ocosingo': {'chiapas'},
#  'ocotepec': {'chiapas', 'puebla'},
#  'ocotlan': {'jalisco'},
#  'ocotlan de morelos': {'oaxaca'},
#  'ocoyoacac': {'mexico'},
#  'ocoyucan': {'puebla'},
#  'ocozocoautla de espinosa': {'chiapas'},
#  'ocuilan': {'mexico'},
#  'ocuituco': {'morelos'},
#  'ojuelos de jalisco': {'jalisco'},
#  'olinala': {'guerrero'},
#  'olintla': {'puebla'},
#  'ometepec': {'guerrero'},
#  'omitlan de juarez': {'hidalgo'},
#  'opichen': {'yucatan'},
#  'oriental': {'puebla'},
#  'ostuacan': {'chiapas'},
#  'osumacinta': {'chiapas'},
#  'otaez': {'durango'},
#  'othon p. blanco': {'quintana roo'},
#  'otumba': {'mexico'},
#  'otzoloapan': {'mexico'},
#  'otzolotepec': {'mexico'},
#  'oxchuc': {'chiapas'},
#  'oxkutzcab': {'yucatan'},
#  'ozumba': {'mexico'},
#  'pabellon de arteaga': {'aguascalientes'},
#  'pachuca de soto': {'hidalgo'},
#  'pacula': {'hidalgo'},
#  'pahuatlan': {'puebla'},
#  'pajacuaran': {'michoacan de ocampo'},
#  'palenque': {'chiapas'},
#  'palizada': {'campeche'},
#  'palmar de bravo': {'puebla'},
#  'panaba': {'yucatan'},
#  'panindicuaro': {'michoacan de ocampo'},
#  'panotla': {'tlaxcala'},
#  'pantelho': {'chiapas'},
#  'pantepec': {'chiapas', 'puebla'},
#  'panuco de coronado': {'durango'},
#  'papalotla': {'mexico'},
#  'papalotla de xicohtencatl': {'tlaxcala'},
#  'paracho': {'michoacan de ocampo'},
#  'paracuaro': {'michoacan de ocampo'},
#  'patzcuaro': {'michoacan de ocampo'},
#  'pedro ascencio alquisiras': {'guerrero'},
#  'pedro escobedo': {'queretaro de arteaga'},
#  'penamiller': {'queretaro de arteaga'},
#  'penjamillo': {'michoacan de ocampo'},
#  'penon blanco': {'durango'},
#  'periban': {'michoacan de ocampo'},
#  'petatlan': {'guerrero'},
#  'petlalcingo': {'puebla'},
#  'peto': {'yucatan'},
#  'piaxtla': {'puebla'},
#  'pichucalco': {'chiapas'},
#  'pihuamo': {'jalisco'},
#  'pijijiapan': {'chiapas'},
#  'pilcaya': {'guerrero'},
#  'pinal de amoles': {'queretaro de arteaga'},
#  'pinotepa de don luis': {'oaxaca'},
#  'pisaflores': {'hidalgo'},
#  'poanas': {'durango'},
#  'polotitlan': {'mexico'},
#  'poncitlan': {'jalisco'},
#  'progreso': {'yucatan'},
#  'progreso de obregon': {'hidalgo'},
#  'puebla': {'puebla'},
#  'pueblo nuevo': {'durango'},
#  'pueblo nuevo solistahuacan': {'chiapas'},
#  'puente de ixtla': {'morelos'},
#  'puerto morelos': {'quintana roo'},
#  'puerto vallarta': {'jalisco'},
#  'pungarabato': {'guerrero'},
#  'purepero': {'michoacan de ocampo'},
#  'puruandiro': {'michoacan de ocampo'},
#  'putla villa de guerrero': {'oaxaca'},
#  'quecholac': {'puebla'},
#  'quechultenango': {'guerrero'},
#  'querendaro': {'michoacan de ocampo'},
#  'queretaro': {'queretaro de arteaga'},
#  'quimixtlan': {'puebla'},
#  'quintana roo': {'yucatan'},
#  'quiroga': {'michoacan de ocampo'},
#  'quitupan': {'jalisco'},
#  'rafael lara grajales': {'puebla'},
#  'rayon': {'chiapas', 'mexico'},
#  'reforma': {'chiapas'},
#  'reforma de pineda': {'oaxaca'},
#  'reyes etla': {'oaxaca'},
#  'rincon chamula san pedro': {'chiapas'},
#  'rincon de romos': {'aguascalientes'},
#  'rio lagartos': {'yucatan'},
#  'rodeo': {'durango'},
#  'rojas de cuauhtemoc': {'oaxaca'},
#  'sabanilla': {'chiapas'},
#  'sacalum': {'yucatan'},
#  'sahuayo': {'michoacan de ocampo'},
#  'salina cruz': {'oaxaca'},
#  'salto de agua': {'chiapas'},
#  'salvador escalante': {'michoacan de ocampo'},
#  'samahil': {'yucatan'},
#  'san agustin amatengo': {'oaxaca'},
#  'san agustin atenango': {'oaxaca'},
#  'san agustin chayuco': {'oaxaca'},
#  'san agustin de las juntas': {'oaxaca'},
#  'san agustin etla': {'oaxaca'},
#  'san agustin loxicha': {'oaxaca'},
#  'san agustin metzquititlan': {'hidalgo'},
#  'san agustin tlacotepec': {'oaxaca'},
#  'san agustin tlaxiaca': {'hidalgo'},
#  'san agustin yatareni': {'oaxaca'},
#  'san andres cabecera nueva': {'oaxaca'},
#  'san andres cholula': {'puebla'},
#  'san andres dinicuiti': {'oaxaca'},
#  'san andres duraznal': {'chiapas'},
#  'san andres huaxpaltepec': {'oaxaca'},
#  'san andres huayapam': {'oaxaca'},
#  'san andres ixtlahuaca': {'oaxaca'},
#  'san andres lagunas': {'oaxaca'},
#  'san andres nuxino': {'oaxaca'},
#  'san andres paxtlan': {'oaxaca'},
#  'san andres sinaxtla': {'oaxaca'},
#  'san andres solaga': {'oaxaca'},
#  'san andres teotilalpam': {'oaxaca'},
#  'san andres tepetlapa': {'oaxaca'},
#  'san andres yaa': {'oaxaca'},
#  'san andres zabache': {'oaxaca'},
#  'san andres zautla': {'oaxaca'},
#  'san antonino castillo velasco': {'oaxaca'},
#  'san antonino el alto': {'oaxaca'},
#  'san antonino monte verde': {'oaxaca'},
#  'san antonio acutla': {'oaxaca'},
#  'san antonio canada': {'puebla'},
#  'san antonio de la cal': {'oaxaca'},
#  'san antonio huitepec': {'oaxaca'},
#  'san antonio la isla': {'mexico'},
#  'san antonio nanahuatipam': {'oaxaca'},
#  'san antonio sinicahua': {'oaxaca'},
#  'san antonio tepetlapa': {'oaxaca'},
#  'san baltazar chichicapam': {'oaxaca'},
#  'san baltazar loxicha': {'oaxaca'},
#  'san baltazar yatzachi el bajo': {'oaxaca'},
#  'san bartolo coyotepec': {'oaxaca'},
#  'san bartolo soyaltepec': {'oaxaca'},
#  'san bartolo tutotepec': {'hidalgo'},
#  'san bartolo yautepec': {'oaxaca'},
#  'san bartolome ayautla': {'oaxaca'},
#  'san bartolome loxicha': {'oaxaca'},
#  'san bartolome quialana': {'oaxaca'},
#  'san bartolome yucuane': {'oaxaca'},
#  'san bartolome zoogocho': {'oaxaca'},
#  'san bernardo': {'durango'},
#  'san bernardo mixtepec': {'oaxaca'},
#  'san blas atempa': {'oaxaca'},
#  'san carlos yautepec': {'oaxaca'},
#  'san cristobal amatlan': {'oaxaca'},
#  'san cristobal amoltepec': {'oaxaca'},
#  'san cristobal de la barranca': {'jalisco'},
#  'san cristobal de las casas': {'chiapas'},
#  'san cristobal lachirioag': {'oaxaca'},
#  'san cristobal suchixtlahuaca': {'oaxaca'},
#  'san damian texoloc': {'tlaxcala'},
#  'san diego de alejandria': {'jalisco'},
#  'san diego la mesa tochimiltzingo': {'puebla'},
#  'san dimas': {'durango'},
#  'san dionisio del mar': {'oaxaca'},
#  'san dionisio ocotepec': {'oaxaca'},
#  'san dionisio ocotlan': {'oaxaca'},
#  'san esteban atatlahuca': {'oaxaca'},
#  'san felipe': {'yucatan'},
#  'san felipe del progreso': {'mexico'},
#  'san felipe jalapa de diaz': {'oaxaca'},
#  'san felipe orizatlan': {'hidalgo'},
#  'san felipe tejalapam': {'oaxaca'},
#  'san felipe teotlalcingo': {'puebla'},
#  'san felipe tepatlan': {'puebla'},
#  'san felipe usila': {'oaxaca'},
#  'san fernando': {'chiapas'},
#  'san francisco cahuacua': {'oaxaca'},
#  'san francisco cajonos': {'oaxaca'},
#  'san francisco chapulapa': {'oaxaca'},
#  'san francisco chindua': {'oaxaca'},
#  'san francisco de los romo': {'aguascalientes'},
#  'san francisco del mar': {'oaxaca'},
#  'san francisco huehuetlan': {'oaxaca'},
#  'san francisco ixhuatan': {'oaxaca'},
#  'san francisco jaltepetongo': {'oaxaca'},
#  'san francisco lachigolo': {'oaxaca'},
#  'san francisco logueche': {'oaxaca'},
#  'san francisco nuxano': {'oaxaca'},
#  'san francisco ozolotepec': {'oaxaca'},
#  'san francisco sola': {'oaxaca'},
#  'san francisco telixtlahuaca': {'oaxaca'},
#  'san francisco teopan': {'oaxaca'},
#  'san francisco tetlanohcan': {'tlaxcala'},
#  'san francisco tlapancingo': {'oaxaca'},
#  'san gabriel': {'jalisco'},
#  'san gabriel chilac': {'puebla'},
#  'san gabriel mixtepec': {'oaxaca'},
#  'san gregorio atzompa': {'puebla'},
#  'san ignacio cerro gordo': {'jalisco'},
#  'san ildefonso amatlan': {'oaxaca'},
#  'san ildefonso sola': {'oaxaca'},
#  'san ildefonso villa alta': {'oaxaca'},
#  'san jacinto amilpas': {'oaxaca'},
#  'san jacinto tlacotepec': {'oaxaca'},
#  'san jeronimo coatlan': {'oaxaca'},
#  'san jeronimo silacayoapilla': {'oaxaca'},
#  'san jeronimo sosola': {'oaxaca'},
#  'san jeronimo taviche': {'oaxaca'},
#  'san jeronimo tecoatl': {'oaxaca'},
#  'san jeronimo tecuanipan': {'puebla'},
#  'san jeronimo tlacochahuaya': {'oaxaca'},
#  'san jeronimo xayacatlan': {'puebla'},
#  'san jeronimo zacualpan': {'tlaxcala'},
#  'san joaquin': {'queretaro de arteaga'},
#  'san jorge nuchita': {'oaxaca'},
#  'san jose ayuquila': {'oaxaca'},
#  'san jose chiapa': {'puebla'},
#  'san jose chiltepec': {'oaxaca'},
#  'san jose de gracia': {'aguascalientes'},
#  'san jose del penasco': {'oaxaca'},
#  'san jose del progreso': {'oaxaca'},
#  'san jose del rincon': {'mexico'},
#  'san jose estancia grande': {'oaxaca'},
#  'san jose independencia': {'oaxaca'},
#  'san jose lachiguiri': {'oaxaca'},
#  'san jose miahuatlan': {'puebla'},
#  'san jose teacalco': {'tlaxcala'},
#  'san jose tenango': {'oaxaca'},
#  'san juan achiutla': {'oaxaca'},
#  'san juan atenco': {'puebla'},
#  'san juan atepec': {'oaxaca'},
#  'san juan atzompa': {'puebla'},
#  'san juan bautista atatlahuca': {'oaxaca'},
#  'san juan bautista coixtlahuaca': {'oaxaca'},
#  'san juan bautista cuicatlan': {'oaxaca'},
#  'san juan bautista guelache': {'oaxaca'},
#  'san juan bautista jayacatlan': {'oaxaca'},
#  'san juan bautista lo de soto': {'oaxaca'},
#  'san juan bautista suchitepec': {'oaxaca'},
#  'san juan bautista tlachichilco': {'oaxaca'},
#  'san juan bautista tlacoatzintepec': {'oaxaca'},
#  'san juan bautista tuxtepec': {'oaxaca'},
#  'san juan bautista valle nacional': {'oaxaca'},
#  'san juan cacahuatepec': {'oaxaca'},
#  'san juan cancuc': {'chiapas'},
#  'san juan chicomezuchil': {'oaxaca'},
#  'san juan chilateca': {'oaxaca'},
#  'san juan cieneguilla': {'oaxaca'},
#  'san juan coatzospam': {'oaxaca'},
#  'san juan colorado': {'oaxaca'},
#  'san juan comaltepec': {'oaxaca'},
#  'san juan cotzocon': {'oaxaca'},
#  'san juan de guadalupe': {'durango'},
#  'san juan de los cues': {'oaxaca'},
#  'san juan de los lagos': {'jalisco'},
#  'san juan del estado': {'oaxaca'},
#  'san juan del rio': {'durango', 'oaxaca', 'queretaro de arteaga'},
#  'san juan diuxi': {'oaxaca'},
#  'san juan evangelista analco': {'oaxaca'},
#  'san juan guelavia': {'oaxaca'},
#  'san juan guichicovi': {'oaxaca'},
#  'san juan huactzinco': {'tlaxcala'},
#  'san juan ihualtepec': {'oaxaca'},
#  'san juan juquila mixes': {'oaxaca'},
#  'san juan juquila vijanos': {'oaxaca'},
#  'san juan lachao': {'oaxaca'},
#  'san juan lachigalla': {'oaxaca'},
#  'san juan lajarcia': {'oaxaca'},
#  'san juan lalana': {'oaxaca'},
#  'san juan mazatlan': {'oaxaca'},
#  'san juan mixtepec -dto. 08 -': {'oaxaca'},
#  'san juan mixtepec -dto. 26 -': {'oaxaca'},
#  'san juan numi': {'oaxaca'},
#  'san juan ozolotepec': {'oaxaca'},
#  'san juan petlapa': {'oaxaca'},
#  'san juan quiahije': {'oaxaca'},
#  'san juan quiotepec': {'oaxaca'},
#  'san juan sayultepec': {'oaxaca'},
#  'san juan tabaa': {'oaxaca'},
#  'san juan tamazola': {'oaxaca'},
#  'san juan teita': {'oaxaca'},
#  'san juan teitipac': {'oaxaca'},
#  'san juan tepeuxila': {'oaxaca'},
#  'san juan teposcolula': {'oaxaca'},
#  'san juan yaee': {'oaxaca'},
#  'san juan yatzona': {'oaxaca'},
#  'san juan yucuita': {'oaxaca'},
#  'san juanito de escobedo': {'jalisco'},
#  'san julian': {'jalisco'},
#  'san lorenzo': {'oaxaca'},
#  'san lorenzo albarradas': {'oaxaca'},
#  'san lorenzo axocomanitla': {'tlaxcala'},
#  'san lorenzo cacaotepec': {'oaxaca'},
#  'san lorenzo cuaunecuiltitla': {'oaxaca'},
#  'san lorenzo texmelucan': {'oaxaca'},
#  'san lorenzo victoria': {'oaxaca'},
#  'san lucas': {'chiapas', 'michoacan de ocampo'},
#  'san lucas camotlan': {'oaxaca'},
#  'san lucas ojitlan': {'oaxaca'},
#  'san lucas quiavini': {'oaxaca'},
#  'san lucas tecopilco': {'tlaxcala'},
#  'san lucas zoquiapam': {'oaxaca'},
#  'san luis acatlan': {'guerrero'},
#  'san luis amatlan': {'oaxaca'},
#  'san luis del cordero': {'durango'},
#  'san marcial ozolotepec': {'oaxaca'},
#  'san marcos': {'guerrero', 'jalisco'},
#  'san marcos arteaga': {'oaxaca'},
#  'san martin de bolanos': {'jalisco'},
#  'san martin de las piramides': {'mexico'},
#  'san martin de los cansecos': {'oaxaca'},
#  'san martin hidalgo': {'jalisco'},
#  'san martin huamelulpam': {'oaxaca'},
#  'san martin itunyoso': {'oaxaca'},
#  'san martin lachila': {'oaxaca'},
#  'san martin peras': {'oaxaca'},
#  'san martin texmelucan': {'puebla'},
#  'san martin tilcajete': {'oaxaca'},
#  'san martin totoltepec': {'puebla'},
#  'san martin toxpalan': {'oaxaca'},
#  'san martin zacatepec': {'oaxaca'},
#  'san mateo atenco': {'mexico'},
#  'san mateo cajonos': {'oaxaca'},
#  'san mateo del mar': {'oaxaca'},
#  'san mateo etlatongo': {'oaxaca'},
#  'san mateo nejapam': {'oaxaca'},
#  'san mateo penasco': {'oaxaca'},
#  'san mateo rio hondo': {'oaxaca'},
#  'san mateo sindihui': {'oaxaca'},
#  'san mateo tlapiltepec': {'oaxaca'},
#  'san mateo yoloxochitlan': {'oaxaca'},
#  'san matias tlalancaleca': {'puebla'},
#  ...}

# %%
df_ratio_estado
# Out:
#                        estado_clean              nom_ent_clean_match  \
# 0                          tlaxcala                         tlaxcala
# 1                    aguascalientes                   aguascalientes
# 2                          guerrero                         guerrero
# 3                            puebla                           puebla
# 4                  ciudad de mexico                 ciudad de mexico
# 5                           chiapas                          chiapas
# 6                           hidalgo                          hidalgo
# 7                      quintana roo                     quintana roo
# 8                            colima                           colima
# 9                           jalisco                          jalisco
# 10                          yucatan                          yucatan
# 11                           oaxaca                           oaxaca
# 12                          morelos                          morelos
# 13                          durango                          durango
# 14              michoacan de ocampo              michoacan de ocampo
# 15  veracruz de ignacio de la llave  veracruz de ignacio de la llave
# 16                           mexico                           mexico
# 17                         campeche                         campeche
# 18             queretaro de arteaga                        queretaro
#
#     ratio_ent                     final_estado
# 0         100                         Tlaxcala
# 1         100                   Aguascalientes
# 2         100                         Guerrero
# 3         100                           Puebla
# 4         100                 Ciudad de México
# 5         100                          Chiapas
# 6         100                          Hidalgo
# 7         100                     Quintana Roo
# 8         100                           Colima
# 9         100                          Jalisco
# 10        100                          Yucatán
# 11        100                           Oaxaca
# 12        100                          Morelos
# 13        100                          Durango
# 14        100              Michoacán de Ocampo
# 15        100  Veracruz de Ignacio de la Llave
# 16        100                           México
# 17        100                         Campeche
# 18         62                        Querétaro

# %%
df_ratio_estado.to_csv('../../data/temp_data/df_ratio_estado.csv', index=False)

# %%
df_ratio_municipio['estado'] = df_ratio_municipio['municipio_clean'].map(mapping_df1)

# %%
df_ratio_municipio['entidad'] = df_ratio_municipio['nom_mun_clean_match'].map(mapping_df1)

# %%
df_ratio_municipio
# Out:
#      estado_clean   nom_ent_clean                  municipio_clean  \
# 0        tlaxcala  aguascalientes     acuamanala de miguel hidalgo
# 1        tlaxcala  aguascalientes               amaxac de guerrero
# 2        tlaxcala  aguascalientes  apetatitlan de antonio carvajal
# 3        tlaxcala  aguascalientes                          apizaco
# 4        tlaxcala  aguascalientes                     atlangatepec
# ...           ...             ...                              ...
# 2044       puebla             NaN                      zihuateutla
# 2045       puebla             NaN                      zinacatepec
# 2046       puebla             NaN                       zongozotla
# 2047       puebla             NaN                        zoquiapan
# 2048       puebla             NaN                        zoquitlan
#
#                   nom_mun_clean_match  ratio_mun  \
# 0        acuamanala de miguel hidalgo        100
# 1                  amaxac de guerrero        100
# 2     apetatitlan de antonio carvajal        100
# 3                             apizaco        100
# 4                        atlangatepec        100
# ...                               ...        ...
# 2044                      zihuateutla        100
# 2045                      zinacatepec        100
# 2046                       zongozotla        100
# 2047                        zoquiapan        100
# 2048                        zoquitlan        100
#
#                       final_municipio      estado     entidad
# 0        Acuamanala de Miguel Hidalgo  {tlaxcala}  {tlaxcala}
# 1                  Amaxac de Guerrero  {tlaxcala}  {tlaxcala}
# 2     Apetatitlán de Antonio Carvajal  {tlaxcala}  {tlaxcala}
# 3                             Apizaco  {tlaxcala}  {tlaxcala}
# 4                        Atlangatepec  {tlaxcala}  {tlaxcala}
# ...                               ...         ...         ...
# 2044                      Zihuateutla    {puebla}    {puebla}
# 2045                      Zinacatepec    {puebla}    {puebla}
# 2046                       Zongozotla    {puebla}    {puebla}
# 2047                        Zoquiapan    {puebla}    {puebla}
# 2048                        Zoquitlán    {puebla}    {puebla}
#
# [2049 rows x 8 columns]

# %%
df_ratio_municipio.drop(columns=['estado_clean', 'nom_ent_clean'])
# Out:
#                       municipio_clean              nom_mun_clean_match  \
# 0        acuamanala de miguel hidalgo     acuamanala de miguel hidalgo
# 1                  amaxac de guerrero               amaxac de guerrero
# 2     apetatitlan de antonio carvajal  apetatitlan de antonio carvajal
# 3                             apizaco                          apizaco
# 4                        atlangatepec                     atlangatepec
# ...                               ...                              ...
# 2044                      zihuateutla                      zihuateutla
# 2045                      zinacatepec                      zinacatepec
# 2046                       zongozotla                       zongozotla
# 2047                        zoquiapan                        zoquiapan
# 2048                        zoquitlan                        zoquitlan
#
#       ratio_mun                  final_municipio      estado     entidad
# 0           100     Acuamanala de Miguel Hidalgo  {tlaxcala}  {tlaxcala}
# 1           100               Amaxac de Guerrero  {tlaxcala}  {tlaxcala}
# 2           100  Apetatitlán de Antonio Carvajal  {tlaxcala}  {tlaxcala}
# 3           100                          Apizaco  {tlaxcala}  {tlaxcala}
# 4           100                     Atlangatepec  {tlaxcala}  {tlaxcala}
# ...         ...                              ...         ...         ...
# 2044        100                      Zihuateutla    {puebla}    {puebla}
# 2045        100                      Zinacatepec    {puebla}    {puebla}
# 2046        100                       Zongozotla    {puebla}    {puebla}
# 2047        100                        Zoquiapan    {puebla}    {puebla}
# 2048        100                        Zoquitlán    {puebla}    {puebla}
#
# [2049 rows x 6 columns]

# %%
df_ratio_municipio.to_csv('../../data/temp_data/df_ratio_municipio.csv', index=False)

# %%
df['estado_clean'] = df['ESTADO'].apply(clean_text)
df['municipio_clean'] = df['MUNICIPIO'].apply(clean_text)

# %%
# Merge df3 with df_ratio_estado on 'estado_clean'
df = df.merge(df_ratio_estado, on='estado_clean', how='left')

# Update 'estado_clean' with 'final_estado' where 'ratio_ent' is 100
df['ESTADO'] = np.where(df['ratio_ent'] >= 84, df['final_estado'], df['estado_clean'])

# Drop the columns from df_ratio_estado
df = df.drop(columns=['nom_ent_clean_match', 'ratio_ent', 'final_estado'])

# %%
# Merge df3 with df_ratio_estado on 'estado_clean'
df = df.merge(df_ratio_municipio, on='municipio_clean', how='left')

# Update 'estado_clean' with 'final_estado' where 'ratio_ent' is 100
df['MUNICIPIO'] = np.where(df['ratio_mun'] >= 84, df['final_municipio'], df['municipio_clean'])

# Drop the columns from df_ratio_estado
df = df.drop(columns=['nom_mun_clean_match', 'ratio_mun', 'final_municipio'])
df = df.drop(columns=['estado_clean', 'municipio_clean', 'estado'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 9
#       7 # Drop the columns from df_ratio_estado
#       8 df = df.drop(columns=['nom_mun_clean_match', 'ratio_mun', 'final_municipio'])
# ----> 9 df = df.drop(columns=['estado_clean', 'municipio_clean', 'estado'])
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['estado_clean', 'estado'] not found in axis"

# %%
df
# Out:
#            ESTADO                     MUNICIPIO  \
# 0        Tlaxcala  Acuamanala de Miguel Hidalgo
# 1        Tlaxcala  Acuamanala de Miguel Hidalgo
# 2        Tlaxcala  Acuamanala de Miguel Hidalgo
# 3        Tlaxcala  Acuamanala de Miguel Hidalgo
# 4        Tlaxcala  Acuamanala de Miguel Hidalgo
# ...           ...                           ...
# 2296768    Puebla                     Zoquitlán
# 2296769    Puebla                     Zoquitlán
# 2296770    Puebla                     Zoquitlán
# 2296771    Puebla                     Zoquitlán
# 2296772    Puebla                     Zoquitlán
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 0        23-PRONAFE-FERT-000018-S000-TL           AGUILA             LIMA
# 1        23-PRONAFE-FERT-000016-S000-TL            CORTE         ESPINOZA
# 2        23-PRONAFE-FERT-000005-S000-TL            CORTE           PICHON
# 3        23-PRONAFE-FERT-000006-S000-TL      CUAHTEPITZI             LUNA
# 4        23-PRONAFE-FERT-000007-S000-TL      CUAHTEPITZI          SANCHEZ
# ...                                 ...              ...              ...
# 2296768  23-PRONAFE-FERT-103188-S000-PL         ZAQUEROZ          SANCHEZ
# 2296769  23-PRONAFE-FERT-103189-S000-PL         ZAQUEROZ          SANCHEZ
# 2296770  23-PRONAFE-FERT-103189-S000-PL         ZAQUEROZ          SANCHEZ
# 2296771  23-PRONAFE-FERT-103190-S000-PL         ZAQUEROZ           TORRES
# 2296772  23-PRONAFE-FERT-103190-S000-PL         ZAQUEROZ           TORRES
#
#                  NOMBRE (S)  PAQUETE         nom_ent
# 0                J. EUGENIO        2  aguascalientes
# 1        MA. PETRA APOLONIA        2  aguascalientes
# 2                    TERESA        2  aguascalientes
# 3                 FLORENCIO        2  aguascalientes
# 4         JOSE SIMON MARTIN        2  aguascalientes
# ...                     ...      ...             ...
# 2296768                JOSE        1             NaN
# 2296769              MARTIN        1         chiapas
# 2296770              MARTIN        1             NaN
# 2296771       ANDRES ELIGIO        2         chiapas
# 2296772       ANDRES ELIGIO        2             NaN
#
# [2296773 rows x 8 columns]

# %% [markdown]
# Si el ratio llega a 100 quiere decir que tenemos lo mismo en las dos variables.

# %%
num_estados = df['ESTADO'].nunique()
num_estados
# Out:
# 19

# %% [markdown]
# En méxico hay 2446 municipios actualmente.

# %% [markdown]
# Aquí hemos creado los diccionarios para mapear estos valores utilizando la biblioteca Fuzzywuzzy, que utiliza la Distancia de Levenshtein para calcular las diferencias entre secuencias (en este caso, cadenas de texto).

# %%
df['ESTADO'].unique()
# Out:
# array(['Tlaxcala', 'Aguascalientes', 'Guerrero', 'Puebla',
#        'Ciudad de México', 'Chiapas', 'Hidalgo', 'Quintana Roo', 'Colima',
#        'Jalisco', 'Yucatán', 'Oaxaca', 'Morelos', 'Durango',
#        'Michoacán de Ocampo', 'Veracruz de Ignacio de la Llave', 'México',
#        'Campeche', 'queretaro de arteaga'], dtype=object)

# %%
df['MUNICIPIO'].unique()
# Out:
# array(['Acuamanala de Miguel Hidalgo', 'Amaxac de Guerrero',
#        'Apetatitlán de Antonio Carvajal', ..., 'Tlacuilotepec',
#        'Xochiltepec', 'Zongozotla'], dtype=object)

# %% [markdown]
# ## 4. Análisis univariado

# %% [markdown]
# ### 4.1 Variables numéricas

# %%
variable_numerica = 'PAQUETE'
if variable_numerica in df.columns:
    df[variable_numerica].hist()
    plt.xlabel(variable_numerica)
    plt.ylabel('Frecuencia')
    plt.title('Histograma de ' + variable_numerica)
    plt.show()
else:
    print(f"La variable numérica '{variable_numerica}' no se encuentra en el dataframe.")

# %% [markdown]
# ### 4.2 Variables categóricas

# %% [markdown]
# ## 5. Detección de outliers

# %% [markdown]
# ### 5.1 IQR

# %%
sns.boxplot(x=df["PAQUETE"])
# Out:
# <Axes: xlabel='PAQUETE'>

# %%
Q1 = df['PAQUETE'].quantile(0.25)
Q3 = df['PAQUETE'].quantile(0.75)
IQR = Q3 - Q1

# %%
ol1 = df[df['PAQUETE'] < (Q1-1.5 * IQR)].shape[0] + df[df['PAQUETE'] > (Q3 + 1.5 * IQR)].shape[0]
ol1
# Out:
# 0

# %% [markdown]
# ### 5.2 Decisiones sobre outliers

# %% [markdown]
# En este caso podemos ver que la única variable numérica no tiene outliers con lo cual continuamos.

# %% [markdown]
# ## 6. Análisis multivariado

# %% [markdown]
# ### 6.1 Matriz de correlación

# %% [markdown]
# ### 6.2 Bivariado: numérico vs numérico

# %% [markdown]
# ### 6.3 Bivariado: numérico vs categórico

# %%
variable_numerica = 'ESTADO'
variable_categorica = 'PAQUETE'

if variable_numerica in df.columns and variable_categorica in df.columns:
    sns.boxplot(x=variable_categorica, y=variable_numerica, data=df)
    plt.xlabel(variable_categorica)
    plt.ylabel(variable_numerica)
    plt.title(f'Box plot de {variable_numerica} por {variable_categorica}')
    plt.show()
else:
    print("Al menos una de las variables no se encuentra en el dataframe.")

# %% [markdown]
# ## 7. Inteligencia artificial aplicada

# %% [markdown]
# ### 7.1 Clustering

# %% [markdown]
# ## 8. Dowload dataset

# %%
df
# Out:
#            ESTADO                     MUNICIPIO  \
# 0        Tlaxcala  Acuamanala de Miguel Hidalgo
# 1        Tlaxcala  Acuamanala de Miguel Hidalgo
# 2        Tlaxcala  Acuamanala de Miguel Hidalgo
# 3        Tlaxcala  Acuamanala de Miguel Hidalgo
# 4        Tlaxcala  Acuamanala de Miguel Hidalgo
# ...           ...                           ...
# 1628670    Puebla                     Zoquitlán
# 1628671    Puebla                     Zoquitlán
# 1628672    Puebla                     Zoquitlán
# 1628673    Puebla                     Zoquitlán
# 1628674    Puebla                     Zoquitlán
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 0        23-PRONAFE-FERT-000018-S000-TL           AGUILA             LIMA
# 1        23-PRONAFE-FERT-000016-S000-TL            CORTE         ESPINOZA
# 2        23-PRONAFE-FERT-000005-S000-TL            CORTE           PICHON
# 3        23-PRONAFE-FERT-000006-S000-TL      CUAHTEPITZI             LUNA
# 4        23-PRONAFE-FERT-000007-S000-TL      CUAHTEPITZI          SANCHEZ
# ...                                 ...              ...              ...
# 1628670  23-PRONAFE-FERT-103186-S000-PL         ZAQUEROZ         MONTALVO
# 1628671  23-PRONAFE-FERT-103187-S000-PL         ZAQUEROZ          SANCHEZ
# 1628672  23-PRONAFE-FERT-103188-S000-PL         ZAQUEROZ          SANCHEZ
# 1628673  23-PRONAFE-FERT-103189-S000-PL         ZAQUEROZ          SANCHEZ
# 1628674  23-PRONAFE-FERT-103190-S000-PL         ZAQUEROZ           TORRES
#
#                  NOMBRE (S)  PAQUETE
# 0                J. EUGENIO        2
# 1        MA. PETRA APOLONIA        2
# 2                    TERESA        2
# 3                 FLORENCIO        2
# 4         JOSE SIMON MARTIN        2
# ...                     ...      ...
# 1628670            ZEFERINO        1
# 1628671           CRECENCIO        2
# 1628672                JOSE        1
# 1628673              MARTIN        1
# 1628674       ANDRES ELIGIO        2
#
# [1628675 rows x 7 columns]

# %%
df = df.sort_values('ESTADO', ascending=True)

# %%
df.to_csv('../../data/productores_autorizados_fertilizantes.csv', index=False)
