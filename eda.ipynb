# %% [markdown]
# # CARGA DE DATOS

# %%
import pandas as pd
import seaborn as sns

def load_datasets():
    ags_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_ags_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    cdmx_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_cdmx_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    chp_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_chp_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    cmp_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_cmp_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    col_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_col_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    dgo_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_dgo_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    edo_mch_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mch_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    edo_mex_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mex_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    edo_mex_df2 = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mex_convo_2.csv', encoding='cp1252', index_col=0, skiprows=1)
    edo_mex_df3 = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mex_convo_3.csv', encoding='cp1252', index_col=0, skiprows=1)
    edo_mor_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_edo_mor_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    gro_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_gro_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    hgo_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_hgo_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    jal_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_jal_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    mor_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_mor_convo_2.csv', encoding='cp1252', index_col=0, skiprows=1)
    oax_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_oax_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    pbl_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_pbl_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    qnro_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_qnro_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    qro_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_qro_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    txl_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_txl_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    vrz_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_vrz_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    yct_df = pd.read_csv('datasets/anexo_unico_i_1er_listado_autori_fertilizantes_23_yct_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    gro2_df = pd.read_csv('datasets/anexo_unico_i_2do_listado_autori_fertilizantes_23_gro_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    jal2_df = pd.read_csv('datasets/anexo_unico_i_2do_listado_autori_fertilizantes_23_jal_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)
    pbl2_df = pd.read_csv('datasets/anexo_unico_i_2do_listado_autori_fertilizantes_23_pbl_convo_1.csv', encoding='cp1252', index_col=0, skiprows=1)

    list = [ags_df, cdmx_df, chp_df, cmp_df, col_df, dgo_df, edo_mch_df, edo_mex_df, edo_mex_df2, edo_mex_df3, edo_mor_df, gro_df, hgo_df, jal_df, mor_df, oax_df, pbl_df, qnro_df, qro_df, txl_df, vrz_df, yct_df, gro2_df, jal2_df, pbl2_df]
    
    merged_df = pd.concat(list, join='inner', ignore_index=True)

    return merged_df

# %%
inegi_df = pd.read_csv('dataset_inegi/dataset_inegi.csv', encoding='cp1252', index_col=0)

# %%
inegi_df
# Out:
#            Estatus  CVE_ENT         NOM_ENT NOM_ABR  CVE_MUN  \
# MAPA
# 10010001       NaN        1  Aguascalientes    Ags.        1
# 10010094       NaN        1  Aguascalientes    Ags.        1
# 10010096       NaN        1  Aguascalientes    Ags.        1
# 10010100       NaN        1  Aguascalientes    Ags.        1
# 10010102       NaN        1  Aguascalientes    Ags.        1
# ...            ...      ...             ...     ...      ...
# 320580039      NaN       32       Zacatecas    Zac.       58
# 320580040      NaN       32       Zacatecas    Zac.       58
# 320580041      NaN       32       Zacatecas    Zac.       58
# 320580042      NaN       32       Zacatecas    Zac.       58
# 320580043      NaN       32       Zacatecas    Zac.       58
#
#                          NOM_MUN  CVE_LOC                 NOM_LOC AMBITO  \
# MAPA
# 10010001          Aguascalientes        1          Aguascalientes      U
# ...

# %%
df = load_datasets()
df
# Out:
#                  ESTADO       MUNICIPIO                           ACUSE  \
# 0        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000510-S000-AS
# 1        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000339-S000-AS
# 2        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000340-S000-AS
# 3        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000511-S000-AS
# 4        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000676-S000-AS
# ...                 ...             ...                             ...
# 1525715          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103370-S000-PL
# 1525716          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103371-S000-PL
# 1525717          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103166-S000-PL
# 1525718          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103373-S000-PL
# 1525719          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103374-S000-PL
#
#         APELLIDO PATERNO APELLIDO MATERNO         NOMBRE (S)  PAQUETE
# ...

# %%
df.columns
# Out:
# Index(['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO',
#        'NOMBRE (S)', 'PAQUETE'],
#       dtype='object')

# %%
df
# Out:
#                  ESTADO       MUNICIPIO                           ACUSE  \
# 0        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000510-S000-AS
# 1        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000339-S000-AS
# 2        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000340-S000-AS
# 3        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000511-S000-AS
# 4        AGUASCALIENTES  AGUASCALIENTES  23-PRONAFE-FERT-000676-S000-AS
# ...                 ...             ...                             ...
# 1525715          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103370-S000-PL
# 1525716          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103371-S000-PL
# 1525717          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103166-S000-PL
# 1525718          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103373-S000-PL
# 1525719          PUEBLA       ZOQUITLAN  23-PRONAFE-FERT-103374-S000-PL
#
#         APELLIDO PATERNO APELLIDO MATERNO         NOMBRE (S)  PAQUETE
# ...

# %%
df.columns
# Out:
# Index(['ESTADO', 'MUNICIPIO', 'ACUSE', 'APELLIDO PATERNO', 'APELLIDO MATERNO',
#        'NOMBRE (S)', 'PAQUETE'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ESTADO              object
# MUNICIPIO           object
# ACUSE               object
# APELLIDO PATERNO    object
# APELLIDO MATERNO    object
# NOMBRE (S)          object
# PAQUETE              int64
# dtype: object

# %%
df = df.astype({
    'ESTADO' : 'string',
    'MUNICIPIO' : 'string',
    'ACUSE' : 'string',
    'APELLIDO PATERNO' : 'string',
    'APELLIDO MATERNO' : 'string',
    'NOMBRE (S)' : 'string',
})

# %%
df.dtypes
# Out:
# ESTADO              string
# MUNICIPIO           string
# ACUSE               string
# APELLIDO PATERNO    string
# APELLIDO MATERNO    string
# NOMBRE (S)          string
# PAQUETE              int64
# dtype: object

# %% [markdown]
# # VALORES DUPLICADOS

# %%
duplicate_rows_df = df[df.duplicated()]
duplicate_rows_df.shape
# Out:
# (0, 7)

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
duplicate_rows_df = df[df.duplicated()]
duplicate_rows_df.shape
# Out:
# (0, 7)

# %% [markdown]
# # FORMATEAR STRINGS

# %%
def clean_text(text):
    text = text.str.strip()  # Eliminar espacios en blanco
    text = text.str.lower()  # Convertir a minúsculas
    text = text.str.replace('[^a-zA-Z\s]', '')  # Eliminar caracteres especiales
    text = text.str.replace('\s+', ' ')  # Eliminar espacios en blanco extras
    text = text.str.replace('^\s+|\s+?$', '')  # Eliminar espacios al inicio y al final
    return text

# %%
columns_to_clean = ['ESTADO', 'MUNICIPIO']

# %%
for col in columns_to_clean:
    df[col] = clean_text(df[col])
# Out:
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_33677/3083008952.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   text = text.str.replace('[^a-zA-Z\s]', '')  # Eliminar caracteres especiales
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_33677/3083008952.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   text = text.str.replace('\s+', ' ')  # Eliminar espacios en blanco extras
# /var/folders/ng/n9ng0wy92t90_49j662nh02c0000gn/T/ipykernel_33677/3083008952.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   text = text.str.replace('^\s+|\s+?$', '')  # Eliminar espacios al inicio y al final

# %%
df['ESTADO'] = df['ESTADO'].str.title()
df['MUNICIPIO'] = df['MUNICIPIO'].str.title()

# %%
df
# Out:
#                  ESTADO       MUNICIPIO                           ACUSE  \
# 0        Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000510-S000-AS
# 1        Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000339-S000-AS
# 2        Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000340-S000-AS
# 3        Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000511-S000-AS
# 4        Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000676-S000-AS
# ...                 ...             ...                             ...
# 1525715          Puebla       Zoquitlan  23-PRONAFE-FERT-103370-S000-PL
# 1525716          Puebla       Zoquitlan  23-PRONAFE-FERT-103371-S000-PL
# 1525717          Puebla       Zoquitlan  23-PRONAFE-FERT-103166-S000-PL
# 1525718          Puebla       Zoquitlan  23-PRONAFE-FERT-103373-S000-PL
# 1525719          Puebla       Zoquitlan  23-PRONAFE-FERT-103374-S000-PL
#
#         APELLIDO PATERNO APELLIDO MATERNO         NOMBRE (S)  PAQUETE
# ...

# %% [markdown]
# # Valores faltantes

# %%
df.isna().sum()
# Out:
# ESTADO                  0
# MUNICIPIO           75512
# ACUSE                   0
# APELLIDO PATERNO     4294
# APELLIDO MATERNO    28213
# NOMBRE (S)           4293
# PAQUETE                 0
# dtype: int64

# %%
(df == 0).sum()
# Out:
# ESTADO              0
# MUNICIPIO           0
# ACUSE               0
# APELLIDO PATERNO    0
# APELLIDO MATERNO    0
# NOMBRE (S)          0
# PAQUETE             0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                  ESTADO       MUNICIPIO                           ACUSE  \
# 84       Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000688-S000-AS
# 141      Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000662-S000-AS
# 295      Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000309-S000-AS
# 443      Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000190-S000-AS
# 518      Aguascalientes  Aguascalientes  23-PRONAFE-FERT-000568-S000-AS
# ...                 ...             ...                             ...
# 1525715          Puebla       Zoquitlan  23-PRONAFE-FERT-103370-S000-PL
# 1525716          Puebla       Zoquitlan  23-PRONAFE-FERT-103371-S000-PL
# 1525717          Puebla       Zoquitlan  23-PRONAFE-FERT-103166-S000-PL
# 1525718          Puebla       Zoquitlan  23-PRONAFE-FERT-103373-S000-PL
# 1525719          Puebla       Zoquitlan  23-PRONAFE-FERT-103374-S000-PL
#
#         APELLIDO PATERNO APELLIDO MATERNO  NOMBRE (S)  PAQUETE
# ...

# %% [markdown]
# Si no hay nombre del productor acreditado lo quitamos. También en el caso de que no haya apellido paterno. Un valor sin nombre y apellido no tiene uso práctico alguno.

# %%
df = df.dropna(subset=['NOMBRE (S)'])
df = df.dropna(subset=['APELLIDO PATERNO'])

# %%
df.isna().sum()
# Out:
# ESTADO                  0
# MUNICIPIO           75512
# ACUSE                   0
# APELLIDO PATERNO        0
# APELLIDO MATERNO    23920
# NOMBRE (S)              0
# PAQUETE                 0
# dtype: int64

# %% [markdown]
# # ORTOGRAFÍA

# %%
# Get unique values in df
unique_estado_df = df['ESTADO'].unique()
unique_municipio_df = df['MUNICIPIO'].unique()

# Get unique values in inegi_df
unique_nom_ent_inegi = inegi_df['NOM_ENT'].unique()
unique_nom_mun_inegi = inegi_df['NOM_MUN'].unique()

# %%
unique_estado_df_list = list(unique_estado_df)
unique_municipio_df_list = list(unique_municipio_df)
unique_nom_ent_inegi_list = list(unique_nom_ent_inegi)
unique_nom_mun_inegi_list = list(unique_nom_mun_inegi)

# Create a DataFrame
unique_values_df = pd.DataFrame({
    'ESTADO': pd.Series(unique_estado_df_list),
    'MUNICIPIO': pd.Series(unique_municipio_df_list),
    'NOM_ENT': pd.Series(unique_nom_ent_inegi_list),
    'NOM_MUN': pd.Series(unique_nom_mun_inegi_list)
})

# %%
df['ESTADO'] = df['ESTADO'].replace('Mxico', 'Mexico')

# %%
unique_values_df.head(50)
# Out:
#                              ESTADO                   MUNICIPIO  \
# 0                    Aguascalientes              Aguascalientes
# 1                  Ciudad De Mexico                    Asientos
# 2                           Chiapas                    Calvillo
# 3                          Campeche                       Cosio
# 4                            Colima                    El Llano
# 5                           Durango                 Jesus Maria
# 6               Michoacan De Ocampo         Pabellon De Arteaga
# 7                            Mexico             Rincon De Romos
# 8                             Mxico   San Francisco De Los Romo
# 9                           Morelos          San Jose De Gracia
# 10                         Guerrero                    Tepezala
# 11                          Hidalgo              Alvaro Obregon
# 12                          Jalisco                    Coyoacan
# 13                           Oaxaca       Cuajimalpa De Morelos
# ...

# %% [markdown]
# # VALORES ATÍPICOS

# %%
df.reset_index(level=0, inplace=True)

# %%
df
# Out:
#            index          ESTADO                MUNICIPIO  \
# 0              0  Aguascalientes           Aguascalientes
# 1              1  Aguascalientes           Aguascalientes
# 2              2  Aguascalientes           Aguascalientes
# 3              3  Aguascalientes           Aguascalientes
# 4              4  Aguascalientes           Aguascalientes
# ...          ...             ...                      ...
# 1521421  1521422          Puebla      Santiago Miahuatlan
# 1521422  1521423          Puebla      Santiago Miahuatlan
# 1521423  1521424          Puebla  Santo Tomas Hueyotlipan
# 1521424  1521425          Puebla  Santo Tomas Hueyotlipan
# 1521425  1521426          Puebla  Santo Tomas Hueyotlipan
#
#                                   ACUSE APELLIDO PATERNO APELLIDO MATERNO  \
# 0        23-PRONAFE-FERT-000510-S000-AS          AGUILAR          AGUILAR
# 1        23-PRONAFE-FERT-000339-S000-AS          AGUILAR           GARCIA
# ...

# %%
df.to_csv('productores_autorizados/productores_autorizados_fertilizantes.csv', index=False)
